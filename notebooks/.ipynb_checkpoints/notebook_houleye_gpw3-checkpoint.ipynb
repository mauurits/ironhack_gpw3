# %%
import pandas as pd 

csv = '../data/air_quality_health_assesments.csv'

df = pd.read_csv(csv)

# %%
df.head()
# Out:
#   City Boundary Specification (LAU/grid) Country Or Territory  \
# 0                   Urban Centres (grid)              Austria
# 1                   Urban Centres (grid)              Belgium
# 2                   Urban Centres (grid)             Bulgaria
# 3                   Urban Centres (grid)               Cyprus
# 4                   Urban Centres (grid)              Czechia
#
#                              City City Code  Total City Population *  Year  \
# 0  All Urban Centres in a Country       NaN                  2573279  2017
# 1  All Urban Centres in a Country       NaN                  3293463  2017
# 2  All Urban Centres in a Country       NaN                  2781161  2017
# 3  All Urban Centres in a Country       NaN                   487725  2017
# 4  All Urban Centres in a Country       NaN                  2555946  2017
#
#   Air Pollutant       Health Risk Scenario  Populated Area [km2]  \
# 0           NO2  WHO_2005_HRAPIE_Scen_Base                   446
# ...

# %%
# Checking for Null Values
df.isnull()  # Returns a DataFrame with True where values are null .isna()
# isnull is an alias of isna
# Out:
#        City Boundary Specification (LAU/grid)  Country Or Territory   City  \
# 0                                       False                 False  False
# 1                                       False                 False  False
# 2                                       False                 False  False
# 3                                       False                 False  False
# 4                                       False                 False  False
# ...                                       ...                   ...    ...
# 77481                                   False                 False  False
# 77482                                   False                 False  False
# 77483                                   False                 False  False
# 77484                                   False                 False  False
# 77485                                   False                 False  False
#
#        City Code  Total City Population *   Year  Air Pollutant  \
# ...

# %%
# Check for null values in each column
df.isna().any()
# Out:
# City Boundary Specification (LAU/grid)               False
# Country Or Territory                                 False
# City                                                 False
# City Code                                             True
# Total City Population *                              False
# Year                                                 False
# Air Pollutant                                        False
# Health Risk Scenario                                 False
# Populated Area [km2]                                 False
# Air Pollution Average [ug/m3]                        False
# Air Pollution Population Weighted Average [ug/m3]    False
# Premature Deaths                                      True
# Premature Deaths - lower CI                           True
# Premature Deaths - upper CI                           True
# Years Of Life Lost                                    True
# Years Of Life Lost - lower CI                         True
# ...

# %%
# Count the number of null values in each column
df.isna().sum()
# Out:
# City Boundary Specification (LAU/grid)                   0
# Country Or Territory                                     0
# City                                                     0
# City Code                                             1484
# Total City Population *                                  0
# Year                                                     0
# Air Pollutant                                            0
# Health Risk Scenario                                     0
# Populated Area [km2]                                     0
# Air Pollution Average [ug/m3]                            0
# Air Pollution Population Weighted Average [ug/m3]        0
# Premature Deaths                                     14620
# Premature Deaths - lower CI                          14620
# Premature Deaths - upper CI                          14620
# Years Of Life Lost                                   14620
# Years Of Life Lost - lower CI                        14620
# ...

# %%
df.dropna()  # Displays how it will look the DataFrame without the rows with null values
# Out:
#       City Boundary Specification (LAU/grid) Country Or Territory     City  \
# 1484          ESTAT Urban Audit Cities (LAU)              Austria     Wien
# 1485          ESTAT Urban Audit Cities (LAU)              Austria     Wien
# 1487          ESTAT Urban Audit Cities (LAU)              Austria     Wien
# 1488          ESTAT Urban Audit Cities (LAU)              Austria     Wien
# 1489          ESTAT Urban Audit Cities (LAU)              Austria     Wien
# ...                                      ...                  ...      ...
# 77480         ESTAT Urban Audit Cities (LAU)             Slovakia  Trencín
# 77482         ESTAT Urban Audit Cities (LAU)             Slovakia  Trencín
# 77483         ESTAT Urban Audit Cities (LAU)             Slovakia  Trencín
# 77484         ESTAT Urban Audit Cities (LAU)             Slovakia  Trencín
# 77485         ESTAT Urban Audit Cities (LAU)             Slovakia  Trencín
#
#       City Code  Total City Population *  Year Air Pollutant  \
# ...

# %%
df.duplicated().sum()
# Out:
# np.int64(0)
