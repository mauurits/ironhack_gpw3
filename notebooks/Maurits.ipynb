# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sns
import matplotlib.pyplot as plt

df = pd.read_csv("/Users/maurits/Documents/Ironhack/week_03/GPW3/ironhack_gpw3/data/cleaned/cleaned_combined_dataset_filtered.csv")
df.head(10)
# Out:
#   city_boundary_specification_(lau/grid)      country_or_territory  \
# 0                   Urban Centres (grid)                   Austria
# 1                   Urban Centres (grid)                   Belgium
# 2                   Urban Centres (grid)                  Bulgaria
# 3                   Urban Centres (grid)                    Cyprus
# 4                   Urban Centres (grid)                   Czechia
# 5                   Urban Centres (grid)                   Germany
# 6                   Urban Centres (grid)                   Denmark
# 7                   Urban Centres (grid)                   Estonia
# 8                   Urban Centres (grid)                     Spain
# 9                   Urban Centres (grid)  European Union Countries
#
#                              city  total_city_population_*  year  \
# 0  All Urban Centres in a Country                  2405646  2005
# 1  All Urban Centres in a Country                  3030639  2005
# 2  All Urban Centres in a Country                  3010927  2005
# 3  All Urban Centres in a Country                   418267  2005
# 4  All Urban Centres in a Country                  2464143  2005
# 5  All Urban Centres in a Country                 25479567  2005
# 6  All Urban Centres in a Country                  1490619  2005
# 7  All Urban Centres in a Country                   522560  2005
# 8  All Urban Centres in a Country                 21279144  2005
# 9       All Urban Centres in EU27                145177261  2005
#
#   air_pollutant       health_risk_scenario  populated_area_[km2]  \
# 0         PM2.5  WHO_2005_HRAPIE_Scen_Base                   446
# 1         PM2.5  WHO_2005_HRAPIE_Scen_Base                   745
# 2         PM2.5  WHO_2005_HRAPIE_Scen_Base                   384
# 3         PM2.5  WHO_2005_HRAPIE_Scen_Base                   131
# 4         PM2.5  WHO_2005_HRAPIE_Scen_Base                   536
# 5         PM2.5  WHO_2005_HRAPIE_Scen_Base                  6769
# 6         PM2.5  WHO_2005_HRAPIE_Scen_Base                   400
# 7         PM2.5  WHO_2005_HRAPIE_Scen_Base                   103
# 8         PM2.5  WHO_2005_HRAPIE_Scen_Base                  2439
# 9         PM2.5  WHO_2005_HRAPIE_Scen_Base                 29537
#
#    air_pollution_average_[ug/m3]  \
# 0                           21.6
# 1                           19.0
# 2                           34.2
# 3                           29.5
# 4                           24.4
# 5                           17.1
# 6                           13.4
# 7                           13.0
# 8                           19.2
# 9                           20.4
#
#    air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# 0                                               22.0            2532.0
# 1                                               19.3            3025.0
# 2                                               34.6            7927.0
# 3                                               29.6             460.0
# 4                                               24.6            3330.0
# 5                                               17.3           24113.0
# 6                                               13.2            1092.0
# 7                                               13.0             451.0
# 8                                               19.8           20098.0
# 9                                               21.5          163356.0
#
#    premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# 0                       1687.0                       3287.0
# 1                       2013.0                       3936.0
# 2                       5363.0                      10157.0
# 3                        310.0                        592.0
# 4                       2231.0                       4315.0
# 5                      16009.0                      31430.0
# 6                        722.0                       1428.0
# 7                        299.0                        590.0
# 8                      13376.0                      26128.0
# 9                     109146.0                     211694.0
#
#    years_of_life_lost  years_of_life_lost_-_lower_ci  \
# 0             27563.0                        18385.0
# 1             32439.0                        21580.0
# 2             85612.0                        57929.0
# 3              4835.0                         3249.0
# 4             36733.0                        24581.0
# 5            272139.0                       180659.0
# 6             12011.0                         7938.0
# 7              5333.0                         3524.0
# 8            220457.0                       146774.0
# 9           1840665.0                      1229764.0
#
#    years_of_life_lost_-_upper_ci      density
# 0                        35772.0  5393.825112
# 1                        42208.0  4067.971812
# 2                       109669.0  7840.955729
# 3                         6231.0  3192.877863
# 4                        47529.0  4597.281716
# 5                       354725.0  3764.155267
# 6                        15715.0  3726.547500
# 7                         6982.0  5073.398058
# 8                       286612.0  8724.536285
# 9                      2385383.0  4915.098385

# %%
filtered_df = df[(df['total_city_population_*'] <= 250000) & (df['density'] >= 3000)]
# filtered_df = df[(df['age'] > 30) | (df['name'] == 'David')]

# %%
filtered_df.head()
# Out:
#     city_boundary_specification_(lau/grid) country_or_territory  \
# 20                    Urban Centres (grid)                Malta
# 48                    Urban Centres (grid)                Malta
# 76                    Urban Centres (grid)                Malta
# 102                   Urban Centres (grid)           Luxembourg
# 130                   Urban Centres (grid)           Luxembourg
#
#                                city  total_city_population_*  year  \
# 20   All Urban Centres in a Country                   248805  2005
# 48   All Urban Centres in a Country                   248805  2005
# 76   All Urban Centres in a Country                   248805  2005
# 102  All Urban Centres in a Country                    86094  2007
# 130  All Urban Centres in a Country                    86094  2007
#
#     air_pollutant             health_risk_scenario  populated_area_[km2]  \
# 20          PM2.5        WHO_2005_HRAPIE_Scen_Base                    57
# 48          PM2.5           WHO_2021_AQG_Scen_Base                    57
# 76          PM2.5  WHO_2021_AQG_Scen_Sensitivity_2                    57
# 102         PM2.5        WHO_2005_HRAPIE_Scen_Base                    28
# 130         PM2.5           WHO_2021_AQG_Scen_Base                    28
#
#      air_pollution_average_[ug/m3]  \
# 20                            21.6
# 48                            21.6
# 76                            21.6
# 102                           13.2
# 130                           13.2
#
#      air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# 20                                                21.7             226.0
# 48                                                21.7             223.0
# 76                                                21.7             284.0
# 102                                               13.2              49.0
# 130                                               13.2              39.0
#
#      premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# 20                         151.0                        293.0
# 48                         171.0                        247.0
# 76                         219.0                        315.0
# 102                         32.0                         64.0
# 130                         30.0                         44.0
#
#      years_of_life_lost  years_of_life_lost_-_lower_ci  \
# 20               2406.0                         1604.0
# 48               2372.0                         1824.0
# 76               3024.0                         2335.0
# 102               553.0                          366.0
# 130               443.0                          338.0
#
#      years_of_life_lost_-_upper_ci      density
# 20                          3124.0  4365.000000
# 48                          2636.0  4365.000000
# 76                          3353.0  4365.000000
# 102                          724.0  3074.785714
# 130                          494.0  3074.785714

# %%
filtered_df.shape
# Out:
# (27260, 17)

# %%
filtered_df.groupby('year')['air_pollution_average_[ug/m3]'].mean()
# Out:
# year
# 2005    20.542083
# 2007    17.798222
# 2008    17.378027
# 2009    17.579847
# 2010    17.278131
# 2011    18.336991
# 2012    16.533215
# 2013    15.768876
# 2014    14.684498
# 2015    15.487031
# 2016    14.297079
# 2017    14.682312
# 2018    14.126445
# 2019    12.650694
# 2020    11.783765
# 2021    11.967358
# Name: air_pollution_average_[ug/m3], dtype: float64

# %%
df_small_dense = df[(df['total_city_population_*'] <= 250000) & (df['density'] >= 3000)]
df_small_nondense = df[(df['total_city_population_*'] <= 250000) & (df['density'] <= 3000)]
df_large_dense = df[(df['total_city_population_*'] >= 1000000) & (df['density'] >= 3000)]
df_large_nondense = df[(df['total_city_population_*'] >= 1000000) & (df['density'] <= 3000)]
df_small_dense_pmd = df[(df['total_city_population_*'] <= 250000) & (df['density'] >= 3000)]
df_small_nondense_pmd = df[(df['total_city_population_*'] <= 250000) & (df['density'] <= 3000)]
df_large_dense_pmd = df[(df['total_city_population_*'] >= 1000000) & (df['density'] >= 3000)]
df_large_nondense_pmd = df[(df['total_city_population_*'] >= 1000000) & (df['density'] <= 3000)]

# %%
# air pollution
df_small_dense.groupby('year')['air_pollution_population_weighted_average_[ug/m3]'].mean().reset_index()
df_small_nondense.groupby('year')['air_pollution_population_weighted_average_[ug/m3]'].mean().reset_index()
df_large_dense.groupby('year')['air_pollution_population_weighted_average_[ug/m3]'].mean().reset_index()
df_large_nondense.groupby('year')['air_pollution_population_weighted_average_[ug/m3]'].mean().reset_index()
# premature deaths
df_small_dense_pmd.groupby('year')['premature_deaths'].mean().reset_index()
df_small_nondense_pmd.groupby('year')['premature_deaths'].mean().reset_index()
df_large_dense_pmd.groupby('year')['premature_deaths'].mean().reset_index()
df_large_nondense_pmd.groupby('year')['premature_deaths'].mean().reset_index()
# Out:
#     year  premature_deaths
# 0   2005       2533.394737
# 1   2007       2082.487179
# 2   2008       2133.282051
# 3   2009       2007.523810
# 4   2010       1988.976190
# 5   2011       1880.333333
# 6   2012       1645.051282
# 7   2013       1581.128205
# 8   2014       1486.102564
# 9   2015       1554.358974
# 10  2016       1464.615385
# 11  2017       1416.500000
# 12  2018       1452.361111
# 13  2019       1223.416667
# 14  2020       1282.388889
# 15  2021       1435.297297

# %%
# import matplotlib.pyplot as plt
# import seaborn as sns

# # Create the main figure and axis
# fig, ax1 = plt.subplots(figsize=(10, 6))

# # Plotting Air Pollution on the primary y-axis
# sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', 
#              data=df_large_dense, ax=ax1, marker='o', label='Large Dense Cities')
# sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', 
#              data=df_small_dense, ax=ax1, marker='o', label='Small Dense Cities')
# sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', 
#              data=df_large_nondense, ax=ax1, marker='o', label='Large Not Dense Cities')
# sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', 
#              data=df_small_nondense, ax=ax1, marker='o', label='Small Not Dense Cities')

# # Set labels and colors for the primary y-axis
# ax1.set_ylabel('Average Air Pollution PM2.5 [µg/m³]', color='blue')
# ax1.tick_params(axis='y', labelcolor='blue')

# # Create a secondary y-axis for premature deaths
# ax2 = ax1.twinx()

# # Plotting Premature Deaths on the secondary y-axis
# sns.lineplot(x='year', y='premature_deaths', 
#              data=df_large_dense_pmd, ax=ax2, marker='o', label='PMD Large Dense Cities', color='darkred')
# sns.lineplot(x='year', y='premature_deaths', 
#              data=df_small_dense_pmd, ax=ax2, marker='o', label='PMD Small Dense Cities', color='orange')
# sns.lineplot(x='year', y='premature_deaths', 
#              data=df_large_nondense_pmd, ax=ax2, marker='o', label='PMD Large Not Dense Cities', color='green')
# sns.lineplot(x='year', y='premature_deaths', 
#              data=df_small_nondense_pmd, ax=ax2, marker='o', label='PMD Small Not Dense Cities', color='purple')

# # Set labels and colors for the secondary y-axis
# ax2.set_ylabel('Premature Deaths', color='red')
# ax2.tick_params(axis='y', labelcolor='red')

# # Adding title and labels
# plt.title('Average Air Pollution and Premature Deaths Over Time in Large vs Small Cities')
# ax1.set_xlabel('Year')

# # Handling the legend
# ax1.legend(loc='upper left')
# ax2.legend(loc='upper right')

# # Display the plot
# plt.show()

# %%
plt.figure(figsize=(10, 6))

sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', data=df_large_dense, marker='o', label='Large Dense Cities')
sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', data=df_small_dense, marker='o', label='Small Dense Cities')
sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', data=df_large_nondense, marker='o', label='Large Not Dense Cities')
sns.lineplot(x='year', y='air_pollution_population_weighted_average_[ug/m3]', data=df_small_nondense, marker='o', label='Small Not Dense Cities')

plt.title('Average Air Pollution Over Time in Large vs Small Cities')
plt.xlabel('Year')
plt.ylabel('Air Pollution PM2.5 [µg/m³]')
plt.grid(True)
plt.legend()
# plt.savefig('average air pollution over time large vs small.jpeg', format='jpeg', dpi=300)
plt.show()

# %%
#Premature deaths in larger and smaller populated areas
#observation: density doesn't seem to have as much as an impact on premature death as suspected, rather the city size.

plt.figure(figsize=(10, 6))

sns.lineplot(x='year', y='premature_deaths', data=df_large_dense_pmd, marker='o', label='PMD Large Dense Cities')
sns.lineplot(x='year', y='premature_deaths', data=df_small_dense_pmd, marker='o', label='PMD Small Dense Cities')
sns.lineplot(x='year', y='premature_deaths', data=df_large_nondense_pmd, marker='o', label='PMD Large Not Dense Cities')
sns.lineplot(x='year', y='premature_deaths', data=df_small_nondense_pmd, marker='o', label='PMD Small Not Dense Cities')

plt.title('Premature Deaths in Large vs Small Cities')
plt.xlabel('Year')
plt.ylabel('Premature Deaths')
plt.grid(True)
plt.legend()
# plt.savefig('premature death large vs small linear.jpeg', format='jpeg', dpi=300)
plt.show()

# %%
#Premature deaths in larger and smaller populated areas
#observation: density doesn't seem to have as much as an impact on premature death as suspected, rather the city size.

import matplotlib.pyplot as plt
import seaborn as sns

# Set up the figure
plt.figure(figsize=(10, 6))

# Plotting the premature deaths data
sns.lineplot(x='year', y='premature_deaths', data=df_large_dense_pmd, marker='o', label='PMD Large Dense Cities')
sns.lineplot(x='year', y='premature_deaths', data=df_small_dense_pmd, marker='o', label='PMD Small Dense Cities')
sns.lineplot(x='year', y='premature_deaths', data=df_large_nondense_pmd, marker='o', label='PMD Large Not Dense Cities')
sns.lineplot(x='year', y='premature_deaths', data=df_small_nondense_pmd, marker='o', label='PMD Small Not Dense Cities')

# Set the y-axis to a logarithmic scale
plt.yscale('log')

# Add titles and labels
plt.title('Premature Deaths in Large vs Small Cities')
plt.xlabel('Year')
plt.ylabel('Premature Deaths (Log Scale)')

# Add grid and legend
plt.grid(True)
plt.legend()
# plt.savefig('premature death large vs small logarithmic.jpeg', format='jpeg', dpi=300)
# Display the plot
plt.show()
