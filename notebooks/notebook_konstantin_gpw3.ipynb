# %%
import pandas as pd
import matplotlib.pyplot as plt
import pandas as pd
import seaborn as sns
import numpy as np

file_path = r"C:\Users\leube\Ironhack\Bootcamp\week_3\ironhack_gpw3\ironhack_gpw3\data\clean\cleaned_combined_dataset_filtered.csv"
df = pd.read_csv(file_path)
df
# Out:
#       city_boundary_specification_(lau/grid) country_or_territory  \
# 0                       Urban Centres (grid)              Austria
# 1                       Urban Centres (grid)              Belgium
# 2                       Urban Centres (grid)             Bulgaria
# 3                       Urban Centres (grid)               Cyprus
# 4                       Urban Centres (grid)              Czechia
# ...                                      ...                  ...
# 70171         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70172         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70173         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70174         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70175         ESTAT Urban Audit Cities (LAU)             Slovakia
#
#                                  city  total_city_population_*  year  \
# 0      All Urban Centres in a Country                  2405646  2005
# 1      All Urban Centres in a Country                  3030639  2005
# 2      All Urban Centres in a Country                  3010927  2005
# 3      All Urban Centres in a Country                   418267  2005
# 4      All Urban Centres in a Country                  2464143  2005
# ...                               ...                      ...   ...
# 70171                         Trencín                    62633  2020
# 70172                         Trencín                    62633  2020
# 70173                         Trencín                    62655  2021
# 70174                         Trencín                    62655  2021
# 70175                         Trencín                    62655  2021
#
#       air_pollutant             health_risk_scenario  populated_area_[km2]  \
# 0             PM2.5        WHO_2005_HRAPIE_Scen_Base                   446
# 1             PM2.5        WHO_2005_HRAPIE_Scen_Base                   745
# 2             PM2.5        WHO_2005_HRAPIE_Scen_Base                   384
# 3             PM2.5        WHO_2005_HRAPIE_Scen_Base                   131
# 4             PM2.5        WHO_2005_HRAPIE_Scen_Base                   536
# ...             ...                              ...                   ...
# 70171         PM2.5           WHO_2021_AQG_Scen_Base                    64
# 70172         PM2.5  WHO_2021_AQG_Scen_Sensitivity_2                    64
# 70173         PM2.5        WHO_2005_HRAPIE_Scen_Base                    64
# 70174         PM2.5           WHO_2021_AQG_Scen_Base                    64
# 70175         PM2.5  WHO_2021_AQG_Scen_Sensitivity_2                    64
#
#        air_pollution_average_[ug/m3]  \
# 0                               21.6
# 1                               19.0
# 2                               34.2
# 3                               29.5
# 4                               24.4
# ...                              ...
# 70171                           14.0
# 70172                           14.0
# 70173                           14.5
# 70174                           14.5
# 70175                           14.5
#
#        air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# 0                                                   22.0            2532.0
# 1                                                   19.3            3025.0
# 2                                                   34.6            7927.0
# 3                                                   29.6             460.0
# 4                                                   24.6            3330.0
# ...                                                  ...               ...
# 70171                                               14.7              46.0
# 70172                                               14.7              69.0
# 70173                                               15.6              72.0
# 70174                                               15.6              63.0
# 70175                                               15.6              91.0
#
#        premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# 0                           1687.0                       3287.0
# 1                           2013.0                       3936.0
# 2                           5363.0                      10157.0
# 3                            310.0                        592.0
# 4                           2231.0                       4315.0
# ...                            ...                          ...
# 70171                         35.0                         51.0
# 70172                         53.0                         76.0
# 70173                         48.0                         94.0
# 70174                         48.0                         70.0
# 70175                         70.0                        101.0
#
#        years_of_life_lost  years_of_life_lost_-_lower_ci  \
# 0                 27563.0                        18385.0
# 1                 32439.0                        21580.0
# 2                 85612.0                        57929.0
# 3                  4835.0                         3249.0
# 4                 36733.0                        24581.0
# ...                   ...                            ...
# 70171               543.0                          415.0
# 70172               807.0                          619.0
# 70173               776.0                          514.0
# 70174               678.0                          519.0
# 70175               980.0                          753.0
#
#        years_of_life_lost_-_upper_ci      density
# 0                            35772.0  5393.825112
# 1                            42208.0  4067.971812
# 2                           109669.0  7840.955729
# 3                             6231.0  3192.877863
# 4                            47529.0  4597.281716
# ...                              ...          ...
# 70171                          606.0   978.640625
# 70172                          897.0   978.640625
# 70173                         1014.0   978.984375
# 70174                          756.0   978.984375
# 70175                         1090.0   978.984375
#
# [70176 rows x 17 columns]

# %%
df_cleaned = df.dropna(axis=1, how='all')
df_cleaned
# Out:
#       city_boundary_specification_(lau/grid) country_or_territory  \
# 0                       Urban Centres (grid)              Austria
# 1                       Urban Centres (grid)              Belgium
# 2                       Urban Centres (grid)             Bulgaria
# 3                       Urban Centres (grid)               Cyprus
# 4                       Urban Centres (grid)              Czechia
# ...                                      ...                  ...
# 70171         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70172         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70173         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70174         ESTAT Urban Audit Cities (LAU)             Slovakia
# 70175         ESTAT Urban Audit Cities (LAU)             Slovakia
#
#                                  city  total_city_population_*  year  \
# 0      All Urban Centres in a Country                  2405646  2005
# 1      All Urban Centres in a Country                  3030639  2005
# 2      All Urban Centres in a Country                  3010927  2005
# 3      All Urban Centres in a Country                   418267  2005
# 4      All Urban Centres in a Country                  2464143  2005
# ...                               ...                      ...   ...
# 70171                         Trencín                    62633  2020
# 70172                         Trencín                    62633  2020
# 70173                         Trencín                    62655  2021
# 70174                         Trencín                    62655  2021
# 70175                         Trencín                    62655  2021
#
#       air_pollutant             health_risk_scenario  populated_area_[km2]  \
# 0             PM2.5        WHO_2005_HRAPIE_Scen_Base                   446
# 1             PM2.5        WHO_2005_HRAPIE_Scen_Base                   745
# 2             PM2.5        WHO_2005_HRAPIE_Scen_Base                   384
# 3             PM2.5        WHO_2005_HRAPIE_Scen_Base                   131
# 4             PM2.5        WHO_2005_HRAPIE_Scen_Base                   536
# ...             ...                              ...                   ...
# 70171         PM2.5           WHO_2021_AQG_Scen_Base                    64
# 70172         PM2.5  WHO_2021_AQG_Scen_Sensitivity_2                    64
# 70173         PM2.5        WHO_2005_HRAPIE_Scen_Base                    64
# 70174         PM2.5           WHO_2021_AQG_Scen_Base                    64
# 70175         PM2.5  WHO_2021_AQG_Scen_Sensitivity_2                    64
#
#        air_pollution_average_[ug/m3]  \
# 0                               21.6
# 1                               19.0
# 2                               34.2
# 3                               29.5
# 4                               24.4
# ...                              ...
# 70171                           14.0
# 70172                           14.0
# 70173                           14.5
# 70174                           14.5
# 70175                           14.5
#
#        air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# 0                                                   22.0            2532.0
# 1                                                   19.3            3025.0
# 2                                                   34.6            7927.0
# 3                                                   29.6             460.0
# 4                                                   24.6            3330.0
# ...                                                  ...               ...
# 70171                                               14.7              46.0
# 70172                                               14.7              69.0
# 70173                                               15.6              72.0
# 70174                                               15.6              63.0
# 70175                                               15.6              91.0
#
#        premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# 0                           1687.0                       3287.0
# 1                           2013.0                       3936.0
# 2                           5363.0                      10157.0
# 3                            310.0                        592.0
# 4                           2231.0                       4315.0
# ...                            ...                          ...
# 70171                         35.0                         51.0
# 70172                         53.0                         76.0
# 70173                         48.0                         94.0
# 70174                         48.0                         70.0
# 70175                         70.0                        101.0
#
#        years_of_life_lost  years_of_life_lost_-_lower_ci  \
# 0                 27563.0                        18385.0
# 1                 32439.0                        21580.0
# 2                 85612.0                        57929.0
# 3                  4835.0                         3249.0
# 4                 36733.0                        24581.0
# ...                   ...                            ...
# 70171               543.0                          415.0
# 70172               807.0                          619.0
# 70173               776.0                          514.0
# 70174               678.0                          519.0
# 70175               980.0                          753.0
#
#        years_of_life_lost_-_upper_ci      density
# 0                            35772.0  5393.825112
# 1                            42208.0  4067.971812
# 2                           109669.0  7840.955729
# 3                             6231.0  3192.877863
# 4                            47529.0  4597.281716
# ...                              ...          ...
# 70171                          606.0   978.640625
# 70172                          897.0   978.640625
# 70173                         1014.0   978.984375
# 70174                          756.0   978.984375
# 70175                         1090.0   978.984375
#
# [70176 rows x 17 columns]

# %%
df.isnull().sum()
# Out:
# city_boundary_specification_(lau/grid)               0
# country_or_territory                                 0
# city                                                 0
# total_city_population_*                              0
# year                                                 0
# air_pollutant                                        0
# health_risk_scenario                                 0
# populated_area_[km2]                                 0
# air_pollution_average_[ug/m3]                        0
# air_pollution_population_weighted_average_[ug/m3]    0
# premature_deaths                                     0
# premature_deaths_-_lower_ci                          0
# premature_deaths_-_upper_ci                          0
# years_of_life_lost                                   0
# years_of_life_lost_-_lower_ci                        0
# years_of_life_lost_-_upper_ci                        0
# density                                              0
# dtype: int64

# %%
def fill_na_with_group_mean(group):
    return group.fillna(group.median())

df['premature_deaths'] = df.groupby(['city', 'year'])['premature_deaths'].transform(fill_na_with_group_mean)

df['premature_deaths']
# Out:
# 0        2532.0
# 1        3025.0
# 2        7927.0
# 3         460.0
# 4        3330.0
#           ...
# 70171      46.0
# 70172      69.0
# 70173      72.0
# 70174      63.0
# 70175      91.0
# Name: premature_deaths, Length: 70176, dtype: float64

# %%
# !pip install plotly
# Out:
# Requirement already satisfied: plotly in c:\users\leube\anaconda3\lib\site-packages (5.9.0)
# Requirement already satisfied: tenacity>=6.2.0 in c:\users\leube\anaconda3\lib\site-packages (from plotly) (8.2.2)

# %%
df['Year'].unique()
# Out:
# array([2017, 2018, 2019, 2020, 2021])

# %%
df['year'] = df['year'].astype(int)  

df_filtered = df[(df['year'] >= 2017) & (df['year'] <= 2021)]

df_grouped = df_filtered.groupby('year')['premature_deaths'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(df_grouped['year'], df_grouped['premature_deaths'], marker='o', linestyle='-', color='b')
plt.title('Premature Deaths Over the Years')
plt.xlabel('Year')
plt.ylabel('Premature Deaths')
plt.grid(True)
plt.xticks(df_grouped['year'])
plt.show()

# %%
df['Year'] = df['Year'].astype(int)  

df_filtered = df[(df['Year'] >= 2017) & (df['Year'] <= 2021)]

df_grouped = df_filtered.groupby('Year')['Air Pollution Population Weighted Average [ug/m3]'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(df_grouped['Year'], df_grouped['Air Pollution Population Weighted Average [ug/m3]'], marker='o', linestyle='-', color='b')
plt.title('Air Pollution Population Weighted Average [ug/m3] over the Years')
plt.xlabel('Year')
plt.ylabel('Air Pollution Population Weighted Average [ug/m3]')
plt.grid(True)
plt.xticks(df_grouped['Year'])
plt.show()

# %%
df['Year'] = df['Year'].astype(int)  

df_filtered = df[(df['Year'] >= 2017) & (df['Year'] <= 2021)]

df_grouped = df_filtered.groupby('Year')['Air Pollution Average [ug/m3]'].sum().reset_index()

plt.figure(figsize=(10, 6))
plt.plot(df_grouped['Year'], df_grouped['Air Pollution Average [ug/m3]'], marker='o', linestyle='-', color='b')
plt.title('Air Pollution Average [ug/m3] over the Years')
plt.xlabel('Year')
plt.ylabel('Air Pollution Average [ug/m3]')
plt.grid(True)
plt.xticks(df_grouped['Year'])
plt.show()

# %%
#graphe air pollution
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))

# Plot 'air_pollution_average_[ug/m3]' vs 'populated_area_[km2]'
sns.lineplot(x='Populated Area [km2]', y='Air Pollution Average [ug/m3]', data=df, label='Average Air Pollution [ug/m3]', marker='o')

# Plot 'air_pollution_population_weighted_average_[ug/m3]' vs 'populated_area_[km2]'
sns.lineplot(x='Populated Area [km2]', y='Air Pollution Population Weighted Average [ug/m3]', data=df, label='Population Weighted Air Pollution [ug/m3]', marker='o')

plt.xscale('log')
plt.yscale('log')

# Add titles and labels
plt.title('Air Pollution Metrics by Populated Area')
plt.xlabel('Populated Area [km²]')
plt.ylabel('Air Pollution [µg/m³]')
plt.legend()
plt.grid(True)

# Display the plot
plt.show()

# %%
min_population = 1000000
min_density = 3000
max_population = 250000
max_density = 1000

large_cities = df[(df['total_city_population_*'] > min_population) & (df['density'] > min_density)]

plt.figure(figsize=(15, 8))
plt.bar(large_cities['city'], large_cities['air_pollution_population_weighted_average_[ug/m3]'], color='skyblue')

plt.xticks(rotation=90)

plt.title('LARGE DENSE')
plt.xlabel('City')
plt.ylabel('Weighted Air Pollution levels')

plt.show()

# %%
min_population = 1000000
min_density = 3000
max_population = 250000
max_density = 1000

large_cities = df[(df['total_city_population_*'] > min_population) & (df['density'] < min_density)]

plt.figure(figsize=(15, 8))
plt.bar(large_cities['city'], large_cities['air_pollution_population_weighted_average_[ug/m3]'], color='skyblue')

plt.xticks(rotation=90)

plt.title('LARGE NOT DENSE')
plt.xlabel('City')
plt.ylabel('Weighted Air Pollution levels')

plt.show()

# %%
min_population = 1000000
min_density = 3000
max_population = 150000
max_density = 1000

small_cities = df[(df['total_city_population_*'] < max_population) & (df['density'] > max_density)]

plt.figure(figsize=(15, 8))
plt.bar(small_cities['city'], small_cities['air_pollution_population_weighted_average_[ug/m3]'], color='skyblue')

plt.xticks(rotation=90)

plt.title('SMALL DENSE')
plt.xlabel('City')
plt.ylabel('Weighted Air Pollution levels')

plt.show()

# %%
min_population = 1000000
min_density = 3000
max_population = 150000
max_density = 1000

small_cities = df[(df['total_city_population_*'] < max_population) & (df['density'] < max_density)]

plt.figure(figsize=(15, 8))
plt.bar(small_cities['city'], small_cities['air_pollution_population_weighted_average_[ug/m3]'], color='skyblue')

plt.xticks(rotation=90)

plt.title('SMALL NOT DENSE')
plt.xlabel('City')
plt.ylabel('Weighted Air Pollution levels')

plt.show()

# %%
# Sample DataFrame (replace this with your actual DataFrame)


# Create a pivot table if needed (e.g., if your data is structured by regions)


# Use seaborn's heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(df.set_index('city'), annot=True, cmap='coolwarm', cbar=True)

plt.title('Heat Map of Population Density')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[9], line 9
#       1 # Sample DataFrame (replace this with your actual DataFrame)
#       2
#       3
#    (...)
#       6
#       7 # Use seaborn's heatmap
#       8 plt.figure(figsize=(8, 6))
# ----> 9 sns.heatmap(df.set_index('city'), annot=True, cmap='coolwarm', cbar=True)
#      11 plt.title('Heat Map of Population Density')
#      12 plt.show()
#
# File ~\Ironhack\Bootcamp\week_3\ironhack_gpw3\ironhack_gpw3\.venv\Lib\site-packages\seaborn\matrix.py:446, in heatmap(data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, linewidths, linecolor, cbar, cbar_kws, cbar_ax, square, xticklabels, yticklabels, mask, ax, **kwargs)
#     365 """Plot rectangular data as a color-encoded matrix.
#     366
#     367 This is an Axes-level function and will draw the heatmap into the
#    (...)
#     443
#     444 """
#     445 # Initialize the plotter object
# --> 446 plotter = _HeatMapper(data, vmin, vmax, cmap, center, robust, annot, fmt,
#     447                       annot_kws, cbar, cbar_kws, xticklabels,
#     448                       yticklabels, mask)
#     450 # Add the pcolormesh kwargs here
#     451 kwargs["linewidths"] = linewidths
#
# File ~\Ironhack\Bootcamp\week_3\ironhack_gpw3\ironhack_gpw3\.venv\Lib\site-packages\seaborn\matrix.py:163, in _HeatMapper.__init__(self, data, vmin, vmax, cmap, center, robust, annot, fmt, annot_kws, cbar, cbar_kws, xticklabels, yticklabels, mask)
#     160 self.ylabel = ylabel if ylabel is not None else ""
#     162 # Determine good default values for the colormapping
# --> 163 self._determine_cmap_params(plot_data, vmin, vmax,
#     164                             cmap, center, robust)
#     166 # Sort out the annotations
#     167 if annot is None or annot is False:
#
# File ~\Ironhack\Bootcamp\week_3\ironhack_gpw3\ironhack_gpw3\.venv\Lib\site-packages\seaborn\matrix.py:197, in _HeatMapper._determine_cmap_params(self, plot_data, vmin, vmax, cmap, center, robust)
#     194 """Use some heuristics to set good defaults for colorbar and range."""
#     196 # plot_data is a np.ma.array instance
# --> 197 calc_data = plot_data.astype(float).filled(np.nan)
#     198 if vmin is None:
#     199     if robust:
#
# ValueError: could not convert string to float: 'Urban Centres (grid)'

# %%
from mpl_toolkits.basemap import Basemap
import matplotlib.pyplot as plt

# Create the map
fig, ax = plt.subplots(figsize=(12, 8))
m = Basemap(projection='merc', llcrnrlat=35, urcrnrlat=65, llcrnrlon=-10, urcrnrlon=30, resolution='i')

# Draw coastlines and country borders
m.drawcoastlines()
m.drawcountries()

# Convert latitude and longitude to x and y coordinates for plotting
x, y = m(data['Longitude'], data['Latitude'])

# Plot the data using a scatter plot
sc = m.scatter(x, y, c=data['Population Density'], cmap='Reds', s=100, edgecolor='k', alpha=0.7)

# Add a colorbar
plt.colorbar(sc, label='Population Density (people per km²)')

plt.title('Population Density in European Cities')
plt.show()
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[4], line 1
# ----> 1 from mpl_toolkits.basemap import Basemap
#       2 import matplotlib.pyplot as plt
#       4 # Create the map
#
# ModuleNotFoundError: No module named 'mpl_toolkits.basemap'

# %%
import matplotlib.pyplot as plt

# Sample DataFrame (replace this with your actual DataFrame)


# Plot the data using a scatter plot
plt.figure(figsize=(10, 8))
sc = plt.scatter(data['Longitude'], data['Latitude'], c=data['Population Density'],
                 cmap='Reds', s=[density / 10 for density in data['Population Density']],
                 edgecolor='k', alpha=0.7)

# Add a colorbar
plt.colorbar(sc, label='Population Density (people per km²)')

# Add labels
for i, city in enumerate(data['City']):
    plt.text(data['Longitude'][i], data['Latitude'][i], city, fontsize=12, ha='right')

plt.title('Population Density in European Cities (Simplified)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
# Plot the data using a scatter plot
plt.figure(figsize=(10, 8))
sc = plt.scatter(df['Longitude'], df['Latitude'], c=df['Population Density'],
                 cmap='Reds', s=df['Population Density'] / 10,
                 edgecolor='k', alpha=0.7)

# Add a colorbar
plt.colorbar(sc, label='Population Density (people per km²)')

# Add labels for each city
for i, city in enumerate(df['City']):
    plt.text(df['Longitude'][i], df['Latitude'][i], city, fontsize=12, ha='right')

plt.title('Population Density in European Cities (Simplified)')
plt.xlabel('Longitude')
plt.ylabel('Latitude')
plt.grid(True)
plt.show()

# %%
import folium
import pandas as pd
from folium.plugins import HeatMap

# Sample DataFrame (replace this with your actual DataFrame)
data = {
    'City': ['CityA', 'CityB', 'CityC', 'CityD'],
    'Latitude': [48.8566, 52.5200, 51.5074, 41.9028],
    'Longitude': [2.3522, 13.4050, -0.1278, 12.4964],
    'Population Density': [20500, 3800, 5600, 4500]  # Population density in people per km²
}

df = pd.DataFrame(data)

# Create a base map centered around Europe
m = folium.Map(location=[54.5260, 15.2551], zoom_start=4)

# Create a list of [latitude, longitude, population_density] for the HeatMap
heat_data = [[row['Latitude'], row['Longitude'], row['Population Density']] for index, row in df.iterrows()]

# Add the heat map to the base map
HeatMap(heat_data).add_to(m)

# Save the map as an HTML file or display it directly
m.save('europe_population_density_heatmap.html')
m
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_68dca238b648c67fe236631f3402b329 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_68dca238b648c67fe236631f3402b329&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_68dca238b648c67fe236631f3402b329 = L.map(
#                 &quot;map_68dca238b648c67fe236631f3402b329&quot;,
#                 {
#                     center: [54.526, 15.2551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_c474f792ded277a023b62a44b3f8e413 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_c474f792ded277a023b62a44b3f8e413.addTo(map_68dca238b648c67fe236631f3402b329);
#
#
#             var heat_map_a173bc9b218a491fa3c3a4b8e71004b2 = L.heatLayer(
#                 [[48.8566, 2.3522, 20500], [52.52, 13.405, 3800], [51.5074, -0.1278, 5600], [41.9028, 12.4964, 4500]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_a173bc9b218a491fa3c3a4b8e71004b2.addTo(map_68dca238b648c67fe236631f3402b329);
#
#
#             tile_layer_c474f792ded277a023b62a44b3f8e413.addTo(map_68dca238b648c67fe236631f3402b329);
#
#
#             heat_map_a173bc9b218a491fa3c3a4b8e71004b2.addTo(map_68dca238b648c67fe236631f3402b329);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time
import folium
from folium.plugins import HeatMap

cities_to_exclude = ['All Urban Centres in a Country', 'All Urban Centres in EU27']
filtered_df = df[~df['city'].isin(cities_to_exclude)]

# Step 2: Filter cities with population greater than 500,000
filtered_df = df[df['total_city_population_*'] > 500000]
filtered_df.to_csv('filtered_cities.csv', index=False)

# Step 3: Geocode the filtered cities with a timeout
geolocator = Nominatim(user_agent="geoapiExercises")

def geocode_city(city_name):
    try:
        location = geolocator.geocode(city_name)
        return location.latitude, location.longitude
    except:
        return None, None

latitudes = []
longitudes = []
for city in filtered_df['city']:
    lat, lon = geocode_city(city)
    latitudes.append(lat)
    longitudes.append(lon)
    print(f"Geocoded {city}: {lat}, {lon}")  # Optional: Print progress
    time.sleep(1)  # Sleep for 1 second between requests to respect the rate limit

filtered_df['Latitude'] = latitudes
filtered_df['Longitude'] = longitudes

# Save the updated DataFrame with coordinates
filtered_df.to_csv('file_with_coordinates.csv', index=False)

# Step 4: Create the heatmap using Folium
m = folium.Map(location=[54.5260, 15.2551], zoom_start=4)
heat_data = [[row['Latitude'], row['Longitude'], row['population_density']] for index, row in filtered_df.iterrows()]
HeatMap(heat_data).add_to(m)

# Save the map as an HTML file or display it directly
m.save('europe_population_density_heatmap.html')
m
# Out:
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in EU27: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in EU27: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in EU27: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in EU27: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None
# Geocoded All Urban Centres in a Country: None, None

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time
import folium
from folium.plugins import HeatMap

# Step 1: Exclude specific cities
cities_to_exclude = ['All Urban Centres in a Country', 'All Urban Centres in EU27']  # Replace with the cities you want to exclude
filtered_df = df[~df['city'].isin(cities_to_exclude)]

filtered_df = filtered_df.drop_duplicates(subset='city')

# Verify the exclusion
print("Cities remaining after exclusion:", filtered_df['city'].unique())

# Step 2: Filter cities with population greater than 500,000
filtered_df = filtered_df[filtered_df['total_city_population_*'] > 1000000]
filtered_df.to_csv('filtered_cities.csv', index=False)

# Step 3: Geocode the filtered cities
geolocator = Nominatim(user_agent="geoapiExercises")

def geocode_city(city_name):
    try:
        location = geolocator.geocode(city_name)
        return location.latitude, location.longitude
    except:
        return None, None

latitudes = []
longitudes = []
for city in filtered_df['city']:
    lat, lon = geocode_city(city)
    latitudes.append(lat)
    longitudes.append(lon)
    print(f"Geocoded {city}: {lat}, {lon}")  # Optional: Print progress
    time.sleep(1)  # Sleep for 1 second between requests to respect the rate limit

filtered_df['Latitude'] = latitudes
filtered_df['Longitude'] = longitudes

filtered_df = filtered_df.dropna(subset=['Latitude', 'Longitude'])

# Save the updated DataFrame with coordinates
filtered_df.to_csv('file_with_coordinates.csv', index=False)

# Step 4: Create the heatmap using Folium
m = folium.Map(location=[54.5260, 15.2551], zoom_start=4)
heat_data = [[row['Latitude'], row['Longitude'], row['density']] for index, row in filtered_df.iterrows()]
HeatMap(heat_data).add_to(m)

# Save the map as an HTML file or display it directly
m.save('europe_population_density_heatmap.html')
m
# Out:
# Cities remaining after exclusion: ['Wien' 'Graz' 'Linz' 'Salzburg' 'Innsbruck' 'Klagenfurt'
#  'Bruxelles / Brussel' 'Antwerpen' 'Gent' 'Charleroi' 'Liège' 'Brugge'
#  'Namur' 'Leuven' 'Mons' 'Kortrijk' 'Oostende' 'Mechelen' 'Mouscron'
#  'La Louvière (greater city)' 'Verviers (greater city)' 'Sofia' 'Plovdiv'
#  'Varna' 'Burgas' 'Pleven' 'Ruse' 'Vidin' 'Stara Zagora' 'Sliven'
#  'Dobrich' 'Shumen' 'Pernik' 'Yambol' 'Haskovo' 'Pazardzhik' 'Blagoevgrad'
#  'Veliko Tarnovo' 'Vratsa' 'Lefkosia' 'Larnaka' 'Lemesos' 'Praha' 'Brno'
#  'Ostrava' 'Plzen' 'Ústí nad Labem' 'Olomouc' 'Liberec' 'Ceské Budejovice'
#  'Hradec Králové' 'Pardubice' 'Zlín' 'Kladno' 'Karlovy Vary' 'Jihlava'
#  'Havírov' 'Most' 'Karviná' 'Chomutov-Jirkov' 'Berlin' 'Hamburg' 'München'
#  'Köln' 'Frankfurt am Main' 'Essen' 'Stuttgart' 'Leipzig' 'Dresden'
#  'Dortmund' 'Düsseldorf' 'Bremen' 'Hannover' 'Nürnberg' 'Bochum'
#  'Bielefeld' 'Halle an der Saale' 'Magdeburg' 'Wiesbaden' 'Göttingen'
#  'Mülheim a.d.Ruhr' 'Moers' 'Darmstadt' 'Trier' 'Freiburg im Breisgau'
#  'Regensburg' 'Frankfurt (Oder)' 'Weimar' 'Schwerin' 'Erfurt' 'Augsburg'
#  'Bonn' 'Karlsruhe' 'Mönchengladbach' 'Mainz' 'Kiel' 'Saarbrücken'
#  'Potsdam' 'Koblenz' 'Rostock' 'Kaiserslautern' 'Iserlohn'
#  'Esslingen am Neckar' 'Hanau' 'Wilhelmshaven' 'Ludwigsburg' 'Tübingen'
#  'Villingen-Schwenningen' 'Flensburg' 'Marburg' 'Konstanz' 'Neumünster'
#  'Brandenburg an der Havel' 'Gießen' 'Lüneburg' 'Bayreuth' 'Celle'
#  'Aschaffenburg' 'Bamberg' 'Plauen' 'Neubrandenburg' 'Fulda'
#  'Kempten (Allgäu)' 'Landshut' 'Sindelfingen' 'Rosenheim'
#  'Frankenthal (Pfalz)' 'Stralsund' 'Friedrichshafen' 'Offenburg' 'Görlitz'
#  'Sankt Augustin' 'Neu-Ulm' 'Schweinfurt' 'Greifswald' 'Wetzlar' 'Speyer'
#  'Passau' 'Dessau-Roßlau' 'Duisburg' 'Mannheim' 'Gelsenkirchen' 'Münster'
#  'Chemnitz' 'Braunschweig' 'Aachen' 'Krefeld' 'Oberhausen' 'Lübeck'
#  'Hagen' 'Kassel' 'Hamm' 'Herne' 'Solingen' 'Osnabrück'
#  'Ludwigshafen am Rhein' 'Leverkusen' 'Oldenburg (Oldenburg)' 'Neuss'
#  'Heidelberg' 'Paderborn' 'Würzburg' 'Recklinghausen' 'Wolfsburg'
#  'Bremerhaven' 'Bottrop' 'Heilbronn' 'Remscheid' 'Offenbach am Main' 'Ulm'
#  'Pforzheim' 'Ingolstadt' 'Gera' 'Salzgitter' 'Reutlingen' 'Fürth'
#  'Cottbus' 'Siegen' 'Bergisch Gladbach' 'Hildesheim' 'Witten' 'Zwickau'
#  'Erlangen' 'Wuppertal' 'Jena' 'Düren, Stadt' 'Bocholt, Stadt' 'København'
#  'Århus' 'Odense' 'Aalborg' 'Tallinn' 'Tartu' 'Narva' 'Athina'
#  'Thessaloniki' 'Pátra' 'Irakleio' 'Larisa' 'Volos' 'Ioannina' 'Kavala'
#  'Kalamata' 'Trikala' 'Serres' 'Katerini' 'Xanthi' 'Chania' 'Madrid'
#  'Barcelona' 'Valencia' 'Sevilla' 'Zaragoza' 'Málaga' 'Murcia'
#  'Valladolid' 'Palma de Mallorca' 'Santiago de Compostela'
#  'Vitoria/Gasteiz' 'Oviedo' 'Pamplona/Iruña' 'Santander' 'Toledo'
#  'Badajoz' 'Logroño' 'Bilbao' 'Córdoba' 'Alicante/Alacant' 'Vigo' 'Gijón'
#  "L'Hospitalet de Llobregat" 'A Coruña' 'Barakaldo' 'Reus' 'Parla' 'Lugo'
#  'San Fernando' 'Girona' 'Cáceres' 'Torrevieja' 'Pozuelo de Alarcón'
#  'Puerto de Santa María, El' 'Coslada' 'Avilés' 'Talavera de la Reina'
#  'Palencia' 'Sant Boi de Llobregat' 'Ferrol' 'Pontevedra' 'Ceuta' 'Gandia'
#  'Rozas de Madrid, Las' 'Guadalajara' 'Sant Cugat del Vallès' 'Manresa'
#  'Getxo' 'Rubí' 'Ciudad Real' 'Benidorm' 'Melilla' 'Viladecans'
#  'Ponferrada' 'San Sebastián de los Reyes' 'Zamora' 'Fuengirola'
#  'Cerdanyola del Vallès' 'Sanlúcar de Barrameda' 'Vilanova i la Geltrú'
#  'Prat de Llobregat, El' 'Línea de la Concepción, La'
#  'Cornellà de Llobregat' 'Majadahonda' 'Torremolinos' 'Castelldefels'
#  'Irun' 'Granollers' 'Elda' 'Mollet del Vallès' 'Granada' 'Badalona'
#  'Móstoles' 'Elche/Elx' 'Cartagena' 'Sabadell' 'Jerez de la Frontera'
#  'Fuenlabrada' 'San Sebastián/Donostia' 'Alcalá de Henares' 'Terrassa'
#  'Leganés' 'Almería' 'Burgos' 'Salamanca' 'Alcorcón' 'Getafe' 'Albacete'
#  'Castellón de la Plana/Castelló de la Plana' 'Huelva' 'Cádiz' 'León'
#  'Tarragona' 'Santa Coloma de Gramenet' 'Jaén' 'Lleida' 'Ourense' 'Mataró'
#  'Dos Hermanas' 'Algeciras' 'Marbella' 'Torrejón de Ardoz' 'Alcobendas'
#  'Alcalá de Guadaíra' 'Alcoy' 'Ávila' 'Benalmádena'
#  'Chiclana de la Frontera' 'Collado Villalba' 'Cuenca' 'Eivissa' 'Linares'
#  'Lorca' 'Mérida' 'Sagunto' 'Torrelavega' 'Valdemoro' 'Paterna' 'Igualada'
#  'Torrent' 'Mislata' 'Rivas-Vaciamadrid' 'Santurtzi'
#  'Esplugues de Llobregat'
#  'San Vicente del Raspeig/Sant Vicent del Raspeig'
#  'Helsinki / Helsingfors' 'Helsinki / Helsingfors (greater city)'
#  'Tampere / Tammerfors' 'Turku / Åbo' 'Oulu' 'Espoo / Esbo'
#  'Vantaa / Vanda' 'Lahti / Lahtis' 'Kuopio' 'Jyväskylä'
#  'Paris (greater city)' 'Lyon' 'Toulouse' 'Strasbourg' 'Bordeaux' 'Nantes'
#  'Lille' 'Montpellier' 'Saint-Etienne' 'Le Havre' 'Rennes' 'Amiens'
#  'Nancy' 'Metz' 'Reims' 'Orléans' 'Dijon' 'Poitiers' 'Clermont-Ferrand'
#  'Caen' 'Limoges' 'Besançon' 'Grenoble' 'Toulon' 'Valenciennes' 'Tours'
#  'Angers' 'Brest' 'Le Mans' 'Avignon' 'Mulhouse' 'Dunkerque' 'Perpignan'
#  'Nîmes' 'Pau' 'Bayonne' 'Annemasse' 'Annecy' 'Lorient' 'Troyes'
#  'Saint-Nazaire' 'La Rochelle' 'Boulogne-sur-Mer' 'Chambéry' 'Chartres'
#  'Calais' 'Béziers' 'Arras' 'Bourges' 'Saint-Brieuc' 'Cherbourg' 'Belfort'
#  'Roanne' 'Saint-Quentin' 'Creil' 'Fréjus' 'Aix-en-Provence' 'Marseille'
#  'Nice' 'Lens-Lievin' 'Douai' 'Valence' 'Rouen' 'Melun' 'Meaux'
#  'Mantes en Yvelines' 'Martigues' 'Colmar' 'Oulu / Uleåborg' 'Umeå'
#  'Tapiola / Niittykumpu' 'Uppsala' 'Västerås' 'Täby' 'Stockholm' 'Haninge'
#  'Södertälje' 'Örebro' 'Norrköping' 'Linköping' 'Borås' 'Rīga' 'Göteborg'
#  'Liepāja' 'Daugavpils' 'Šiauliai' 'Panevėžys' 'Klaipėda' 'Helsingborg'
#  'Lund' 'Kaunas' 'Greve / Ishøj' 'Malmö' 'Vilnius' 'Gdynia' 'Suwałki'
#  'Słupsk' 'Gdańsk' 'Elbląg' 'Swords / Malahide' 'Blanchardstown' 'Ełk'
#  'Tczew' 'Koszalin' 'Dublin' 'Olsztyn' 'Lütten Klein' 'Limerick'
#  'Białystok' 'Grudziądz' 'Łomża' 'Szczecin' 'Harburg' 'Kasztelanka'
#  'Stargard Szczeciński' 'Bydgoszcz' 'Piła' 'Toruń' 'Cork' 'Leeuwarden'
#  'Groningen' 'Gröpelingen / Vegesack' 'Inowrocław' 'Assen' 'Delmenhorst'
#  'Włocławek' 'Płock' 'Legionowo' 'Gorzów Wielkopolski' 'Siedlce' 'Gniezno'
#  'Hoorn' 'Alkmaar' 'Warszawa' 'Beverwijk/Heemskerk' 'Purmerend' 'Lelystad'
#  'Zwolle' 'Poznań' 'Haarlem' 'Almere' 'Haarlemmermeer' 'Amsterdam'
#  'Almelo' 'Deventer' 'Hilversum' 'Hengelo' 'Soest / Baarn' 'Apeldoorn'
#  'Leiden' 'Alphen aan den Rijn' 'Amersfoort' 'Enschede' 'Zgierz'
#  'Vleuten / De Meern' 'Zoetermeer' 'Utrecht' 'Gouda' "'s-Gravenhage"
#  'Pijnacker / Berkel en Rodenrijs' 'Nieuwegein / IJsselstein' 'Veenendaal'
#  'Łódź' 'Ede' 'Zielona Góra' 'Kalisz' 'Pabianice' 'Arnhem' 'Rotterdam'
#  'Spijkenisse' 'Tomaszów Mazowiecki' 'Dordrecht' 'Radom' 'Chełm'
#  'Gütersloh' 'Ostrów Wielkopolski' 'Lublin' 'Nijmegen' 'Bocholt' 'Oss'
#  'Głogów' 'Piotrków Trybunalski' "'s-Hertogenbosch" 'Belchatow' 'Breda'
#  'Marl' 'Roosendaal' 'Tilburg' 'Bergen op Zoom' 'Lünen' 'Lubin' 'Helmond'
#  'Ostrowiec Świętokrzyski' 'Eindhoven' 'Zamość' 'Moers / Rheinhausen'
#  'Ruhrgebiet' 'Kapellen / Ekeren' 'Venlo' 'Legnica' 'Kielce'
#  'Gevelsberg / Schwelm' 'Wrocław' 'Lüdenscheid' 'Stalowa Wola'
#  'Solingen / Wuppertal' 'Częstochowa' 'Benrath' 'Jelenia Góra'
#  'Sittard-Geleen' 'Świdnica' 'Boulogne-sur-mer' 'Heerlen' 'Opole'
#  'Wałbrzych' 'Maastricht' 'Herzogenrath' 'Porz' 'Mielec' 'Düren'
#  'Verviers / Dison' 'Rzeszów' 'Lens' 'La Louvière' 'Gliwice' 'Mysłowice'
#  'Quaregnon / Frameries' 'Górnośląski Związek Metropolitalny' 'Tarnów'
#  'Chomutov / Jirkov' 'Przemyśl' 'Tychy' 'Kraków' 'Rybnik'
#  'Jastrzębie-Zdrój' 'Bielsko-Biała' 'Bad Soden am Taunus / Kelkheim'
#  'Poruba' 'Nowy Sącz' 'Havířov' 'Hrabuvka' 'Rüsselsheim am Main' 'Plzeň'
#  'Luxembourg' 'Žilina' 'Mannheim/Ludwigshafen' 'Martin' 'Košice'
#  'Cergy-Pontoise' 'Poissy' 'Les Clayes-sous-Bois' 'Banská Bystrica'
#  'Maurepas / Montigny-le-Bretonneux' 'České Budějovice' 'Botoşani' 'Paris'
#  'Suceava' 'Vaihingen / Möhringen' 'Göppingen' 'Trnava' 'Nitra' 'Miskolc'
#  'Nyíregyháza' 'Iaşi' 'Satu Mare' 'Baia Mare' 'Ulm/Neu-Ulm' 'Bratislava'
#  'Haunstetten' 'Piatra Neamţ' 'Debrecen' 'Bistrita' 'Gyõr' 'Tatabánya'
#  'Bacău' 'Rákosliget' 'Budapest' 'Érd' 'Oradea' 'Bârlad' 'Szolnok'
#  'Cluj-Napoca' 'Székesfehérvár' 'Târgu Mureş' 'Bregenz' 'Szombathely'
#  'Veszprém' 'Kecskemét' 'Focşani' 'Sfântu Gheorghe' 'Galaţi' 'Tulcea'
#  'Braşov' 'Brăila' 'Arad' 'Szeged' 'Sibiu' 'Maribor' 'Deva' 'Hunedoara'
#  'Bolzano' 'Buzău' 'Pécs' 'Timişoara' 'Ploieşti' 'Ljubljana' 'Udine'
#  'Râmnicu Vâlcea' 'Târgovişte' 'Trento' 'Pordenone' 'Zagreb' 'Osijek'
#  'Piteşti' 'Târgu Jiu' 'Lecco' 'Constanţa' 'Varese' 'Como' 'Trieste'
#  'Treviso' 'Bergamo' 'Chambery' 'Gallarate' 'Călărași' 'Bucureşti'
#  'Saronno' 'Busto Arsizio' 'Vicenza' 'Brescia' 'Mestre' 'Novara' 'Verona'
#  'Venezia' 'Rijeka' 'Slatina' 'Drobeta-Turnu Severin' 'Padova' 'Milano'
#  'Craiova' 'Pavia' 'Cremona' 'Giurgiu' 'Piacenza' 'Torino' 'Asti'
#  'Alessandria' 'Ferrara' 'Parma' 'Carpi' "Reggio nell'Emilia" 'Modena'
#  'Sassuolo' 'Bologna' 'Ravenna' 'Genova' 'Savona' 'Zadar' 'Forlì'
#  'La Spezia' 'Rimini' 'Nimes' 'Pesaro' 'Prato' 'Firenze' 'Split' 'Pisa'
#  'Ancona' 'Antibes' 'Cannes' 'Martigues / Port-de-Bouc' 'Livorno' 'Arezzo'
#  'Braga' 'La Seyne-sur-Mer / Sanary-sur-Mer' 'Perugia' 'Póvoa de Varzim'
#  'Porto' 'Grosseto' 'Arcozelo / Espinho' 'Terni' 'Pescara' 'Ajaccio'
#  'Coimbra' 'San Severo' 'Manfredonia' 'Sant Cugat del Vallès/Rubí'
#  'el Masnou' 'Roma' 'Ostia' 'El Prat de Llobregat' 'Foggia' 'Barletta'
#  'Anzio / Nettuno' 'Latina' 'Trani' 'Bisceglie' 'Cerignola' 'Andria'
#  'Molfetta' 'Bitonto' 'Bari' 'Santa Monica' 'Caserta' 'Acerra' 'Altamura'
#  'Avellino' 'Brindisi' 'San Giuseppe Vesuviano' 'Pozzuoli / Bacoli'
#  'Matera' 'Napoli' 'Salerno' 'Sassari' 'Battipaglia' 'Taranto' 'Lecce'
#  'Lisboa' 'Almada' 'Barreiro' 'Amora' 'Setúbal'
#  "El Port de Sagunt / Canet d'En Berenguer" 'Cosenza' 'Alcoi/Alcoy'
#  'Cagliari' 'Tomares' 'Messina' 'Reggio di Calabria' 'Bagheria' 'Palermo'
#  'Trapani' 'Acireale' 'Catania' 'Siracusa' 'Gela' 'Ragusa' 'Valletta'
#  'Slavonski Brod' 'Pula-Pola' 'Békéscsaba' 'Kaposvár' 'Eger' 'Dunaújváros'
#  'Zalaegerszeg' 'Sopron' 'Galway' 'Waterford' 'Milano (greater city)'
#  'Napoli (greater city)' 'Campobasso' 'Potenza' 'Catanzaro' 'Massa'
#  'Anzio' 'Monza' 'Giugliano in Campania' "L'Aquila" 'Panevezys' 'Alytus'
#  'Klaipeda' 'Siauliai' 'Riga' 'Liepaja' 'Jelgava' "Greater 's-Gravenhage"
#  'Greater Amsterdam' 'Greater Rotterdam' 'Greater Utrecht'
#  'Greater Eindhoven' 'Greater Arnhem' 'Greater Heerlen'
#  'Greater Sittard-Geleen' 'Greater Nissewaard' 'Greater Middelburg'
#  'Greater Haarlem' 'Zaanstad' 'Greater Leiden' 'Greater Ede'
#  'Greater Alkmaar' 'Greater Heemskerk' 'Greater Soest' 'Lódz' 'Wroclaw'
#  'Poznan' 'Gdansk' 'Katowice' 'Górnoslaski Zwiazek Metropolitalny'
#  'Bialystok' 'Torun' 'Nowy Sacz' 'Suwalki' 'Konin' 'Zory' 'Czestochowa'
#  'Plock' 'Slupsk' 'Jastrzebie-Zdrój' 'Pila' 'Inowroclaw'
#  'Ostrowiec Swietokrzyski' 'Stargard Szczecinski' 'Przemysl' 'Zamosc'
#  'Chelm' 'Glogów' 'Lomza' 'Leszno' 'Swidnica' 'Elk' 'Sosnowiec' 'Zabrze'
#  'Bytom' 'Bielsko-Biala' 'Ruda Slaska' 'Walbrzych' 'Elblag' 'Wloclawek'
#  'Chorzów' 'Grudziadz' 'Lisboa (greater city)' 'Porto (greater city)'
#  'Aveiro' 'Faro' 'Seixal' 'Amadora' 'Odivelas' 'Viseu' 'Valongo'
#  'Viana do Castelo' 'Paredes' 'Sintra' 'Vila Nova de Gaia' 'Matosinhos'
#  'Gondomar' 'Guimarães' 'Vila Franca de Xira' 'Bucuresti' 'Timisoara'
#  'Braila' 'Bacau' 'Târgu Mures' 'Piatra Neamt' 'Calarasi' 'Alba Iulia'
#  'Focsani' 'Târgoviste' 'Roman' 'Constanta' 'Iasi' 'Galati' 'Brasov'
#  'Ploiesti' 'Pitesti' 'Buzau' 'Botosani' 'Stockholm (greater city)'
#  'Jönköping' 'Sodertalje' 'Kosice' 'Presov' 'Zilina' 'Trencín']
# Geocoded Wien: 48.2083537, 16.3725042
# Geocoded Bruxelles / Brussel: 50.8550018, 4.3512333761166175
# Geocoded Sofia: -15.2538402, 48.2562163
# Geocoded Praha: 50.0874654, 14.4212535
# Geocoded Berlin: 52.5108638, 13.3989421
# Geocoded Hamburg: 53.550341, 10.000654
# Geocoded München: 48.1371079, 11.5753822
# Geocoded Köln: 50.938361, 6.959974
# Geocoded København: 55.6867243, 12.5700724
# Geocoded Athina: 37.9755648, 23.7348324
# Geocoded Madrid: 40.4167047, -3.7035825
# Geocoded Barcelona: 41.3828939, 2.1774322
# Geocoded Paris (greater city): None, None
# Geocoded Lyon: 45.7578137, 4.8320114
# Geocoded Stockholm: 59.3251172, 18.0710935
# Geocoded Warszawa: 52.2337172, 21.071432235636493
# Geocoded Amsterdam: 52.3730796, 4.8924534
# Geocoded Ruhrgebiet: 51.51751795, 7.1439182017132445
# Geocoded Górnośląski Związek Metropolitalny: None, None
# Geocoded Paris: 48.8534951, 2.3483915
# Geocoded Budapest: 47.4978789, 19.0402383
# Geocoded Bucureşti: 44.4361414, 26.1027202
# Geocoded Milano: 45.4641943, 9.1896346
# Geocoded Torino: 45.0677551, 7.6824892
# Geocoded Roma: 41.8933203, 12.4829321
# Geocoded Napoli: 40.8358846, 14.2487679
# Geocoded Lisboa: 38.7077507, -9.1365919
# Geocoded Milano (greater city): -37.8626426, 144.902709
# Geocoded Napoli (greater city): -41.0500152, 145.9067524
# Geocoded Greater Rotterdam: 51.9262584, 4.4503145
# Geocoded Górnoslaski Zwiazek Metropolitalny: None, None
# Geocoded Lisboa (greater city): None, None
# Geocoded Porto (greater city): None, None
# Geocoded Bucuresti: 44.4361414, 26.1027202
# Geocoded Stockholm (greater city): None, None
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_3deae8927803b6362067be6c4671d168 {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_3deae8927803b6362067be6c4671d168&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_3deae8927803b6362067be6c4671d168 = L.map(
#                 &quot;map_3deae8927803b6362067be6c4671d168&quot;,
#                 {
#                     center: [54.526, 15.2551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_8ee0fd529f7deebaf3093c92b0ab2482 = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_8ee0fd529f7deebaf3093c92b0ab2482.addTo(map_3deae8927803b6362067be6c4671d168);
#
#
#             var heat_map_9c6e56027303a5dca36fb8dfb1efea00 = L.heatLayer(
#                 [[48.2083537, 16.3725042, 4174.982716049382], [50.8550018, 4.3512333761166175, 5947.343589743589], [-15.2538402, 48.2562163, 2291.886824324324], [50.0874654, 14.4212535, 2363.1753731343283], [52.5108638, 13.3989421, 3916.043132803632], [53.550341, 10.000654, 2424.8178243774573], [48.1371079, 11.5753822, 4102.755043227666], [50.938361, 6.959974, 2854.9921875], [55.6867243, 12.5700724, 3018.4044715447158], [37.9755648, 23.7348324, 6918.90693069307], [40.4167047, -3.7035825, 11355.661478599222], [41.3828939, 2.1774322, 17441.022471910113], [45.7578137, 4.8320114, 4049.549019607843], [59.3251172, 18.0710935, 3844.873287671233], [52.2337172, 21.071432235636493, 5642.986798679868], [52.3730796, 4.8924534, 4873.042056074766], [51.51751795, 7.1439182017132445, 3002.8817427385893], [48.8534951, 2.3483915, 6764.405152224825], [47.4978789, 19.0402383, 5329.157190635451], [44.4361414, 26.1027202, 9786.367924528302], [45.4641943, 9.1896346, 4098.707462686567], [45.0677551, 7.6824892, 6187.204545454545], [41.8933203, 12.4829321, 5196.819672131148], [40.8358846, 14.2487679, 5092.208835341366], [38.7077507, -9.1365919, 5432.248427672956], [-37.8626426, 144.902709, 2930.895645028759], [-41.0500152, 145.9067524, 3230.438775510204], [51.9262584, 4.4503145, 2548.99381443299], [44.4361414, 26.1027202, 7075.3265993266]],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_9c6e56027303a5dca36fb8dfb1efea00.addTo(map_3deae8927803b6362067be6c4671d168);
#
#
#             tile_layer_8ee0fd529f7deebaf3093c92b0ab2482.addTo(map_3deae8927803b6362067be6c4671d168);
#
#
#             heat_map_9c6e56027303a5dca36fb8dfb1efea00.addTo(map_3deae8927803b6362067be6c4671d168);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
import pandas as pd
from geopy.geocoders import Nominatim
import time
import folium
from folium.plugins import HeatMap

# Step 1: Exclude specific cities
cities_to_exclude = ['All Urban Centres in a Country', 'All Urban Centres in EU27']  # Replace with the cities you want to exclude
filtered_df = df[~df['city'].isin(cities_to_exclude)]

filtered_df = filtered_df.drop_duplicates(subset='city')

# Verify the exclusion
print("Cities remaining after exclusion:", filtered_df['city'].unique())

# Step 2: Filter cities with population greater than 500,000
filtered_df = filtered_df[filtered_df['total_city_population_*'] > 1000000]
filtered_df.to_csv('filtered_cities.csv', index=False)

# Step 3: Geocode the filtered cities
geolocator = Nominatim(user_agent="geoapiExercises")

def geocode_city(city_name):
    try:
        location = geolocator.geocode(city_name)
        return location.latitude, location.longitude
    except:
        return None, None

latitudes = []
longitudes = []
for city in filtered_df['city']:
    lat, lon = geocode_city(city)
    latitudes.append(lat)
    longitudes.append(lon)
    print(f"Geocoded {city}: {lat}, {lon}")  # Optional: Print progress
    time.sleep(1)  # Sleep for 1 second between requests to respect the rate limit

filtered_df['Latitude'] = latitudes
filtered_df['Longitude'] = longitudes

filtered_df = filtered_df.dropna(subset=['Latitude', 'Longitude'])

# Save the updated DataFrame with coordinates
filtered_df.to_csv('file_with_coordinates.csv', index=False)

# Step 4: Create the heatmap using Folium
m = folium.Map(location=[54.5260, 15.2551], zoom_start=4)
heat_data = [[row['Latitude'], row['Longitude'], row['air_pollution_population_weighted_average_[ug/m3']] for index, row in filtered_df.iterrows()]
HeatMap(heat_data).add_to(m)

# Save the map as an HTML file or display it directly
m.save('europe_population_density_heatmap.html')
m
# Out:
# Cities remaining after exclusion: ['Wien' 'Graz' 'Linz' 'Salzburg' 'Innsbruck' 'Klagenfurt'
#  'Bruxelles / Brussel' 'Antwerpen' 'Gent' 'Charleroi' 'Liège' 'Brugge'
#  'Namur' 'Leuven' 'Mons' 'Kortrijk' 'Oostende' 'Mechelen' 'Mouscron'
#  'La Louvière (greater city)' 'Verviers (greater city)' 'Sofia' 'Plovdiv'
#  'Varna' 'Burgas' 'Pleven' 'Ruse' 'Vidin' 'Stara Zagora' 'Sliven'
#  'Dobrich' 'Shumen' 'Pernik' 'Yambol' 'Haskovo' 'Pazardzhik' 'Blagoevgrad'
#  'Veliko Tarnovo' 'Vratsa' 'Lefkosia' 'Larnaka' 'Lemesos' 'Praha' 'Brno'
#  'Ostrava' 'Plzen' 'Ústí nad Labem' 'Olomouc' 'Liberec' 'Ceské Budejovice'
#  'Hradec Králové' 'Pardubice' 'Zlín' 'Kladno' 'Karlovy Vary' 'Jihlava'
#  'Havírov' 'Most' 'Karviná' 'Chomutov-Jirkov' 'Berlin' 'Hamburg' 'München'
#  'Köln' 'Frankfurt am Main' 'Essen' 'Stuttgart' 'Leipzig' 'Dresden'
#  'Dortmund' 'Düsseldorf' 'Bremen' 'Hannover' 'Nürnberg' 'Bochum'
#  'Bielefeld' 'Halle an der Saale' 'Magdeburg' 'Wiesbaden' 'Göttingen'
#  'Mülheim a.d.Ruhr' 'Moers' 'Darmstadt' 'Trier' 'Freiburg im Breisgau'
#  'Regensburg' 'Frankfurt (Oder)' 'Weimar' 'Schwerin' 'Erfurt' 'Augsburg'
#  'Bonn' 'Karlsruhe' 'Mönchengladbach' 'Mainz' 'Kiel' 'Saarbrücken'
#  'Potsdam' 'Koblenz' 'Rostock' 'Kaiserslautern' 'Iserlohn'
#  'Esslingen am Neckar' 'Hanau' 'Wilhelmshaven' 'Ludwigsburg' 'Tübingen'
#  'Villingen-Schwenningen' 'Flensburg' 'Marburg' 'Konstanz' 'Neumünster'
#  'Brandenburg an der Havel' 'Gießen' 'Lüneburg' 'Bayreuth' 'Celle'
#  'Aschaffenburg' 'Bamberg' 'Plauen' 'Neubrandenburg' 'Fulda'
#  'Kempten (Allgäu)' 'Landshut' 'Sindelfingen' 'Rosenheim'
#  'Frankenthal (Pfalz)' 'Stralsund' 'Friedrichshafen' 'Offenburg' 'Görlitz'
#  'Sankt Augustin' 'Neu-Ulm' 'Schweinfurt' 'Greifswald' 'Wetzlar' 'Speyer'
#  'Passau' 'Dessau-Roßlau' 'Duisburg' 'Mannheim' 'Gelsenkirchen' 'Münster'
#  'Chemnitz' 'Braunschweig' 'Aachen' 'Krefeld' 'Oberhausen' 'Lübeck'
#  'Hagen' 'Kassel' 'Hamm' 'Herne' 'Solingen' 'Osnabrück'
#  'Ludwigshafen am Rhein' 'Leverkusen' 'Oldenburg (Oldenburg)' 'Neuss'
#  'Heidelberg' 'Paderborn' 'Würzburg' 'Recklinghausen' 'Wolfsburg'
#  'Bremerhaven' 'Bottrop' 'Heilbronn' 'Remscheid' 'Offenbach am Main' 'Ulm'
#  'Pforzheim' 'Ingolstadt' 'Gera' 'Salzgitter' 'Reutlingen' 'Fürth'
#  'Cottbus' 'Siegen' 'Bergisch Gladbach' 'Hildesheim' 'Witten' 'Zwickau'
#  'Erlangen' 'Wuppertal' 'Jena' 'Düren, Stadt' 'Bocholt, Stadt' 'København'
#  'Århus' 'Odense' 'Aalborg' 'Tallinn' 'Tartu' 'Narva' 'Athina'
#  'Thessaloniki' 'Pátra' 'Irakleio' 'Larisa' 'Volos' 'Ioannina' 'Kavala'
#  'Kalamata' 'Trikala' 'Serres' 'Katerini' 'Xanthi' 'Chania' 'Madrid'
#  'Barcelona' 'Valencia' 'Sevilla' 'Zaragoza' 'Málaga' 'Murcia'
#  'Valladolid' 'Palma de Mallorca' 'Santiago de Compostela'
#  'Vitoria/Gasteiz' 'Oviedo' 'Pamplona/Iruña' 'Santander' 'Toledo'
#  'Badajoz' 'Logroño' 'Bilbao' 'Córdoba' 'Alicante/Alacant' 'Vigo' 'Gijón'
#  "L'Hospitalet de Llobregat" 'A Coruña' 'Barakaldo' 'Reus' 'Parla' 'Lugo'
#  'San Fernando' 'Girona' 'Cáceres' 'Torrevieja' 'Pozuelo de Alarcón'
#  'Puerto de Santa María, El' 'Coslada' 'Avilés' 'Talavera de la Reina'
#  'Palencia' 'Sant Boi de Llobregat' 'Ferrol' 'Pontevedra' 'Ceuta' 'Gandia'
#  'Rozas de Madrid, Las' 'Guadalajara' 'Sant Cugat del Vallès' 'Manresa'
#  'Getxo' 'Rubí' 'Ciudad Real' 'Benidorm' 'Melilla' 'Viladecans'
#  'Ponferrada' 'San Sebastián de los Reyes' 'Zamora' 'Fuengirola'
#  'Cerdanyola del Vallès' 'Sanlúcar de Barrameda' 'Vilanova i la Geltrú'
#  'Prat de Llobregat, El' 'Línea de la Concepción, La'
#  'Cornellà de Llobregat' 'Majadahonda' 'Torremolinos' 'Castelldefels'
#  'Irun' 'Granollers' 'Elda' 'Mollet del Vallès' 'Granada' 'Badalona'
#  'Móstoles' 'Elche/Elx' 'Cartagena' 'Sabadell' 'Jerez de la Frontera'
#  'Fuenlabrada' 'San Sebastián/Donostia' 'Alcalá de Henares' 'Terrassa'
#  'Leganés' 'Almería' 'Burgos' 'Salamanca' 'Alcorcón' 'Getafe' 'Albacete'
#  'Castellón de la Plana/Castelló de la Plana' 'Huelva' 'Cádiz' 'León'
#  'Tarragona' 'Santa Coloma de Gramenet' 'Jaén' 'Lleida' 'Ourense' 'Mataró'
#  'Dos Hermanas' 'Algeciras' 'Marbella' 'Torrejón de Ardoz' 'Alcobendas'
#  'Alcalá de Guadaíra' 'Alcoy' 'Ávila' 'Benalmádena'
#  'Chiclana de la Frontera' 'Collado Villalba' 'Cuenca' 'Eivissa' 'Linares'
#  'Lorca' 'Mérida' 'Sagunto' 'Torrelavega' 'Valdemoro' 'Paterna' 'Igualada'
#  'Torrent' 'Mislata' 'Rivas-Vaciamadrid' 'Santurtzi'
#  'Esplugues de Llobregat'
#  'San Vicente del Raspeig/Sant Vicent del Raspeig'
#  'Helsinki / Helsingfors' 'Helsinki / Helsingfors (greater city)'
#  'Tampere / Tammerfors' 'Turku / Åbo' 'Oulu' 'Espoo / Esbo'
#  'Vantaa / Vanda' 'Lahti / Lahtis' 'Kuopio' 'Jyväskylä'
#  'Paris (greater city)' 'Lyon' 'Toulouse' 'Strasbourg' 'Bordeaux' 'Nantes'
#  'Lille' 'Montpellier' 'Saint-Etienne' 'Le Havre' 'Rennes' 'Amiens'
#  'Nancy' 'Metz' 'Reims' 'Orléans' 'Dijon' 'Poitiers' 'Clermont-Ferrand'
#  'Caen' 'Limoges' 'Besançon' 'Grenoble' 'Toulon' 'Valenciennes' 'Tours'
#  'Angers' 'Brest' 'Le Mans' 'Avignon' 'Mulhouse' 'Dunkerque' 'Perpignan'
#  'Nîmes' 'Pau' 'Bayonne' 'Annemasse' 'Annecy' 'Lorient' 'Troyes'
#  'Saint-Nazaire' 'La Rochelle' 'Boulogne-sur-Mer' 'Chambéry' 'Chartres'
#  'Calais' 'Béziers' 'Arras' 'Bourges' 'Saint-Brieuc' 'Cherbourg' 'Belfort'
#  'Roanne' 'Saint-Quentin' 'Creil' 'Fréjus' 'Aix-en-Provence' 'Marseille'
#  'Nice' 'Lens-Lievin' 'Douai' 'Valence' 'Rouen' 'Melun' 'Meaux'
#  'Mantes en Yvelines' 'Martigues' 'Colmar' 'Oulu / Uleåborg' 'Umeå'
#  'Tapiola / Niittykumpu' 'Uppsala' 'Västerås' 'Täby' 'Stockholm' 'Haninge'
#  'Södertälje' 'Örebro' 'Norrköping' 'Linköping' 'Borås' 'Rīga' 'Göteborg'
#  'Liepāja' 'Daugavpils' 'Šiauliai' 'Panevėžys' 'Klaipėda' 'Helsingborg'
#  'Lund' 'Kaunas' 'Greve / Ishøj' 'Malmö' 'Vilnius' 'Gdynia' 'Suwałki'
#  'Słupsk' 'Gdańsk' 'Elbląg' 'Swords / Malahide' 'Blanchardstown' 'Ełk'
#  'Tczew' 'Koszalin' 'Dublin' 'Olsztyn' 'Lütten Klein' 'Limerick'
#  'Białystok' 'Grudziądz' 'Łomża' 'Szczecin' 'Harburg' 'Kasztelanka'
#  'Stargard Szczeciński' 'Bydgoszcz' 'Piła' 'Toruń' 'Cork' 'Leeuwarden'
#  'Groningen' 'Gröpelingen / Vegesack' 'Inowrocław' 'Assen' 'Delmenhorst'
#  'Włocławek' 'Płock' 'Legionowo' 'Gorzów Wielkopolski' 'Siedlce' 'Gniezno'
#  'Hoorn' 'Alkmaar' 'Warszawa' 'Beverwijk/Heemskerk' 'Purmerend' 'Lelystad'
#  'Zwolle' 'Poznań' 'Haarlem' 'Almere' 'Haarlemmermeer' 'Amsterdam'
#  'Almelo' 'Deventer' 'Hilversum' 'Hengelo' 'Soest / Baarn' 'Apeldoorn'
#  'Leiden' 'Alphen aan den Rijn' 'Amersfoort' 'Enschede' 'Zgierz'
#  'Vleuten / De Meern' 'Zoetermeer' 'Utrecht' 'Gouda' "'s-Gravenhage"
#  'Pijnacker / Berkel en Rodenrijs' 'Nieuwegein / IJsselstein' 'Veenendaal'
#  'Łódź' 'Ede' 'Zielona Góra' 'Kalisz' 'Pabianice' 'Arnhem' 'Rotterdam'
#  'Spijkenisse' 'Tomaszów Mazowiecki' 'Dordrecht' 'Radom' 'Chełm'
#  'Gütersloh' 'Ostrów Wielkopolski' 'Lublin' 'Nijmegen' 'Bocholt' 'Oss'
#  'Głogów' 'Piotrków Trybunalski' "'s-Hertogenbosch" 'Belchatow' 'Breda'
#  'Marl' 'Roosendaal' 'Tilburg' 'Bergen op Zoom' 'Lünen' 'Lubin' 'Helmond'
#  'Ostrowiec Świętokrzyski' 'Eindhoven' 'Zamość' 'Moers / Rheinhausen'
#  'Ruhrgebiet' 'Kapellen / Ekeren' 'Venlo' 'Legnica' 'Kielce'
#  'Gevelsberg / Schwelm' 'Wrocław' 'Lüdenscheid' 'Stalowa Wola'
#  'Solingen / Wuppertal' 'Częstochowa' 'Benrath' 'Jelenia Góra'
#  'Sittard-Geleen' 'Świdnica' 'Boulogne-sur-mer' 'Heerlen' 'Opole'
#  'Wałbrzych' 'Maastricht' 'Herzogenrath' 'Porz' 'Mielec' 'Düren'
#  'Verviers / Dison' 'Rzeszów' 'Lens' 'La Louvière' 'Gliwice' 'Mysłowice'
#  'Quaregnon / Frameries' 'Górnośląski Związek Metropolitalny' 'Tarnów'
#  'Chomutov / Jirkov' 'Przemyśl' 'Tychy' 'Kraków' 'Rybnik'
#  'Jastrzębie-Zdrój' 'Bielsko-Biała' 'Bad Soden am Taunus / Kelkheim'
#  'Poruba' 'Nowy Sącz' 'Havířov' 'Hrabuvka' 'Rüsselsheim am Main' 'Plzeň'
#  'Luxembourg' 'Žilina' 'Mannheim/Ludwigshafen' 'Martin' 'Košice'
#  'Cergy-Pontoise' 'Poissy' 'Les Clayes-sous-Bois' 'Banská Bystrica'
#  'Maurepas / Montigny-le-Bretonneux' 'České Budějovice' 'Botoşani' 'Paris'
#  'Suceava' 'Vaihingen / Möhringen' 'Göppingen' 'Trnava' 'Nitra' 'Miskolc'
#  'Nyíregyháza' 'Iaşi' 'Satu Mare' 'Baia Mare' 'Ulm/Neu-Ulm' 'Bratislava'
#  'Haunstetten' 'Piatra Neamţ' 'Debrecen' 'Bistrita' 'Gyõr' 'Tatabánya'
#  'Bacău' 'Rákosliget' 'Budapest' 'Érd' 'Oradea' 'Bârlad' 'Szolnok'
#  'Cluj-Napoca' 'Székesfehérvár' 'Târgu Mureş' 'Bregenz' 'Szombathely'
#  'Veszprém' 'Kecskemét' 'Focşani' 'Sfântu Gheorghe' 'Galaţi' 'Tulcea'
#  'Braşov' 'Brăila' 'Arad' 'Szeged' 'Sibiu' 'Maribor' 'Deva' 'Hunedoara'
#  'Bolzano' 'Buzău' 'Pécs' 'Timişoara' 'Ploieşti' 'Ljubljana' 'Udine'
#  'Râmnicu Vâlcea' 'Târgovişte' 'Trento' 'Pordenone' 'Zagreb' 'Osijek'
#  'Piteşti' 'Târgu Jiu' 'Lecco' 'Constanţa' 'Varese' 'Como' 'Trieste'
#  'Treviso' 'Bergamo' 'Chambery' 'Gallarate' 'Călărași' 'Bucureşti'
#  'Saronno' 'Busto Arsizio' 'Vicenza' 'Brescia' 'Mestre' 'Novara' 'Verona'
#  'Venezia' 'Rijeka' 'Slatina' 'Drobeta-Turnu Severin' 'Padova' 'Milano'
#  'Craiova' 'Pavia' 'Cremona' 'Giurgiu' 'Piacenza' 'Torino' 'Asti'
#  'Alessandria' 'Ferrara' 'Parma' 'Carpi' "Reggio nell'Emilia" 'Modena'
#  'Sassuolo' 'Bologna' 'Ravenna' 'Genova' 'Savona' 'Zadar' 'Forlì'
#  'La Spezia' 'Rimini' 'Nimes' 'Pesaro' 'Prato' 'Firenze' 'Split' 'Pisa'
#  'Ancona' 'Antibes' 'Cannes' 'Martigues / Port-de-Bouc' 'Livorno' 'Arezzo'
#  'Braga' 'La Seyne-sur-Mer / Sanary-sur-Mer' 'Perugia' 'Póvoa de Varzim'
#  'Porto' 'Grosseto' 'Arcozelo / Espinho' 'Terni' 'Pescara' 'Ajaccio'
#  'Coimbra' 'San Severo' 'Manfredonia' 'Sant Cugat del Vallès/Rubí'
#  'el Masnou' 'Roma' 'Ostia' 'El Prat de Llobregat' 'Foggia' 'Barletta'
#  'Anzio / Nettuno' 'Latina' 'Trani' 'Bisceglie' 'Cerignola' 'Andria'
#  'Molfetta' 'Bitonto' 'Bari' 'Santa Monica' 'Caserta' 'Acerra' 'Altamura'
#  'Avellino' 'Brindisi' 'San Giuseppe Vesuviano' 'Pozzuoli / Bacoli'
#  'Matera' 'Napoli' 'Salerno' 'Sassari' 'Battipaglia' 'Taranto' 'Lecce'
#  'Lisboa' 'Almada' 'Barreiro' 'Amora' 'Setúbal'
#  "El Port de Sagunt / Canet d'En Berenguer" 'Cosenza' 'Alcoi/Alcoy'
#  'Cagliari' 'Tomares' 'Messina' 'Reggio di Calabria' 'Bagheria' 'Palermo'
#  'Trapani' 'Acireale' 'Catania' 'Siracusa' 'Gela' 'Ragusa' 'Valletta'
#  'Slavonski Brod' 'Pula-Pola' 'Békéscsaba' 'Kaposvár' 'Eger' 'Dunaújváros'
#  'Zalaegerszeg' 'Sopron' 'Galway' 'Waterford' 'Milano (greater city)'
#  'Napoli (greater city)' 'Campobasso' 'Potenza' 'Catanzaro' 'Massa'
#  'Anzio' 'Monza' 'Giugliano in Campania' "L'Aquila" 'Panevezys' 'Alytus'
#  'Klaipeda' 'Siauliai' 'Riga' 'Liepaja' 'Jelgava' "Greater 's-Gravenhage"
#  'Greater Amsterdam' 'Greater Rotterdam' 'Greater Utrecht'
#  'Greater Eindhoven' 'Greater Arnhem' 'Greater Heerlen'
#  'Greater Sittard-Geleen' 'Greater Nissewaard' 'Greater Middelburg'
#  'Greater Haarlem' 'Zaanstad' 'Greater Leiden' 'Greater Ede'
#  'Greater Alkmaar' 'Greater Heemskerk' 'Greater Soest' 'Lódz' 'Wroclaw'
#  'Poznan' 'Gdansk' 'Katowice' 'Górnoslaski Zwiazek Metropolitalny'
#  'Bialystok' 'Torun' 'Nowy Sacz' 'Suwalki' 'Konin' 'Zory' 'Czestochowa'
#  'Plock' 'Slupsk' 'Jastrzebie-Zdrój' 'Pila' 'Inowroclaw'
#  'Ostrowiec Swietokrzyski' 'Stargard Szczecinski' 'Przemysl' 'Zamosc'
#  'Chelm' 'Glogów' 'Lomza' 'Leszno' 'Swidnica' 'Elk' 'Sosnowiec' 'Zabrze'
#  'Bytom' 'Bielsko-Biala' 'Ruda Slaska' 'Walbrzych' 'Elblag' 'Wloclawek'
#  'Chorzów' 'Grudziadz' 'Lisboa (greater city)' 'Porto (greater city)'
#  'Aveiro' 'Faro' 'Seixal' 'Amadora' 'Odivelas' 'Viseu' 'Valongo'
#  'Viana do Castelo' 'Paredes' 'Sintra' 'Vila Nova de Gaia' 'Matosinhos'
#  'Gondomar' 'Guimarães' 'Vila Franca de Xira' 'Bucuresti' 'Timisoara'
#  'Braila' 'Bacau' 'Târgu Mures' 'Piatra Neamt' 'Calarasi' 'Alba Iulia'
#  'Focsani' 'Târgoviste' 'Roman' 'Constanta' 'Iasi' 'Galati' 'Brasov'
#  'Ploiesti' 'Pitesti' 'Buzau' 'Botosani' 'Stockholm (greater city)'
#  'Jönköping' 'Sodertalje' 'Kosice' 'Presov' 'Zilina' 'Trencín']
# Geocoded Wien: None, None
# Geocoded Bruxelles / Brussel: None, None
# Geocoded Sofia: None, None
# Geocoded Praha: None, None
# Geocoded Berlin: None, None
# Geocoded Hamburg: None, None
# Geocoded München: None, None
# Geocoded Köln: None, None
# Geocoded København: None, None
# Geocoded Athina: None, None
# Geocoded Madrid: None, None
# Geocoded Barcelona: None, None
# Geocoded Paris (greater city): None, None
# Geocoded Lyon: None, None
# Geocoded Stockholm: None, None
# Geocoded Warszawa: None, None
# Geocoded Amsterdam: None, None
# Geocoded Ruhrgebiet: None, None
# Geocoded Górnośląski Związek Metropolitalny: None, None
# Geocoded Paris: None, None
# Geocoded Budapest: None, None
# Geocoded Bucureşti: None, None
# Geocoded Milano: None, None
# Geocoded Torino: None, None
# Geocoded Roma: None, None
# Geocoded Napoli: None, None
# Geocoded Lisboa: None, None
# Geocoded Milano (greater city): None, None
# Geocoded Napoli (greater city): None, None
# Geocoded Greater Rotterdam: None, None
# Geocoded Górnoslaski Zwiazek Metropolitalny: None, None
# Geocoded Lisboa (greater city): None, None
# Geocoded Porto (greater city): None, None
# Geocoded Bucuresti: None, None
# Geocoded Stockholm (greater city): None, None
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><span style="color:#565656">Make this Notebook Trusted to load map: File -> Trust Notebook</span><iframe srcdoc="&lt;!DOCTYPE html&gt;
# &lt;html&gt;
# &lt;head&gt;
#
#     &lt;meta http-equiv=&quot;content-type&quot; content=&quot;text/html; charset=UTF-8&quot; /&gt;
#
#         &lt;script&gt;
#             L_NO_TOUCH = false;
#             L_DISABLE_3D = false;
#         &lt;/script&gt;
#
#     &lt;style&gt;html, body {width: 100%;height: 100%;margin: 0;padding: 0;}&lt;/style&gt;
#     &lt;style&gt;#map {position:absolute;top:0;bottom:0;right:0;left:0;}&lt;/style&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://code.jquery.com/jquery-3.7.1.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/js/bootstrap.bundle.min.js&quot;&gt;&lt;/script&gt;
#     &lt;script src=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.js&quot;&gt;&lt;/script&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/leaflet@1.9.3/dist/leaflet.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/bootstrap@5.2.2/dist/css/bootstrap.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://netdna.bootstrapcdn.com/bootstrap/3.0.0/css/bootstrap-glyphicons.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/npm/@fortawesome/fontawesome-free@6.2.0/css/all.min.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdnjs.cloudflare.com/ajax/libs/Leaflet.awesome-markers/2.0.2/leaflet.awesome-markers.css&quot;/&gt;
#     &lt;link rel=&quot;stylesheet&quot; href=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium/folium/templates/leaflet.awesome.rotate.min.css&quot;/&gt;
#
#             &lt;meta name=&quot;viewport&quot; content=&quot;width=device-width,
#                 initial-scale=1.0, maximum-scale=1.0, user-scalable=no&quot; /&gt;
#             &lt;style&gt;
#                 #map_e344ee099c17e190694a8e6f1f8a746c {
#                     position: relative;
#                     width: 100.0%;
#                     height: 100.0%;
#                     left: 0.0%;
#                     top: 0.0%;
#                 }
#                 .leaflet-container { font-size: 1rem; }
#             &lt;/style&gt;
#
#     &lt;script src=&quot;https://cdn.jsdelivr.net/gh/python-visualization/folium@main/folium/templates/leaflet_heat.min.js&quot;&gt;&lt;/script&gt;
# &lt;/head&gt;
# &lt;body&gt;
#
#
#             &lt;div class=&quot;folium-map&quot; id=&quot;map_e344ee099c17e190694a8e6f1f8a746c&quot; &gt;&lt;/div&gt;
#
# &lt;/body&gt;
# &lt;script&gt;
#
#
#             var map_e344ee099c17e190694a8e6f1f8a746c = L.map(
#                 &quot;map_e344ee099c17e190694a8e6f1f8a746c&quot;,
#                 {
#                     center: [54.526, 15.2551],
#                     crs: L.CRS.EPSG3857,
#                     zoom: 4,
#                     zoomControl: true,
#                     preferCanvas: false,
#                 }
#             );
#
#
#
#
#
#             var tile_layer_13596ae3ca22b5cef91aad9802d757af = L.tileLayer(
#                 &quot;https://tile.openstreetmap.org/{z}/{x}/{y}.png&quot;,
#                 {&quot;attribution&quot;: &quot;\u0026copy; \u003ca href=\&quot;https://www.openstreetmap.org/copyright\&quot;\u003eOpenStreetMap\u003c/a\u003e contributors&quot;, &quot;detectRetina&quot;: false, &quot;maxNativeZoom&quot;: 19, &quot;maxZoom&quot;: 19, &quot;minZoom&quot;: 0, &quot;noWrap&quot;: false, &quot;opacity&quot;: 1, &quot;subdomains&quot;: &quot;abc&quot;, &quot;tms&quot;: false}
#             );
#
#
#             tile_layer_13596ae3ca22b5cef91aad9802d757af.addTo(map_e344ee099c17e190694a8e6f1f8a746c);
#
#
#             var heat_map_a3c186e72f4d169c2266ef414c7d3c4b = L.heatLayer(
#                 [],
#                 {&quot;blur&quot;: 15, &quot;maxZoom&quot;: 18, &quot;minOpacity&quot;: 0.5, &quot;radius&quot;: 25}
#             );
#
#
#             heat_map_a3c186e72f4d169c2266ef414c7d3c4b.addTo(map_e344ee099c17e190694a8e6f1f8a746c);
#
#
#             tile_layer_13596ae3ca22b5cef91aad9802d757af.addTo(map_e344ee099c17e190694a8e6f1f8a746c);
#
#
#             heat_map_a3c186e72f4d169c2266ef414c7d3c4b.addTo(map_e344ee099c17e190694a8e6f1f8a746c);
#
# &lt;/script&gt;
# &lt;/html&gt;" style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>
