# %%
import numpy as np
import pandas as pd
import matplotlib as mp
import seaborn as sns
import matplotlib.pyplot as plt

# %%
data_quality_air= pd.read_csv('../data/air_quality_health_assesments.csv')

# %%
data_quality_air.head()

# %%
combined_dataset_allyears=pd.read_csv(path)

# %%
combined_dataset_allyears.describe()

# %%
#PART ABOUT DATA CLEANING IN Main NOTEBOOK (code hard to translate due to work with different paths)

# %%
#path = r"C:\Users\tania\Documents\FormationDataIronhack\ProjectWeek3\ironhack_gpw3\data\cleaned\cleaned_combined_dataset_gpw3.csv"
#path = r"C:\Users\tania\Documents\FormationDataIronhack\ProjectWeek3\ironhack_gpw3\data\cleaned\cleaned_combined_dataset_density.csv"
path = r"C:\Users\tania\Documents\FormationDataIronhack\ProjectWeek3\ironhack_gpw3\data\cleaned\cleaned_combined_dataset_filtered.csv"
df_cleanedgpw3=pd.read_csv(path)

# %%
pathpics = r"C:\Users\tania\Documents\FormationDataIronhack\ProjectWeek3\ironhack_gpw3\figures"

# %%
df_cleanedgpw3.head()
# Out:
#   city_boundary_specification_(lau/grid) country_or_territory  \
# 0                   Urban Centres (grid)              Austria
# 1                   Urban Centres (grid)              Belgium
# 2                   Urban Centres (grid)             Bulgaria
# 3                   Urban Centres (grid)               Cyprus
# 4                   Urban Centres (grid)              Czechia
#
#                              city  total_city_population_*  year  \
# 0  All Urban Centres in a Country                  2405646  2005
# 1  All Urban Centres in a Country                  3030639  2005
# 2  All Urban Centres in a Country                  3010927  2005
# 3  All Urban Centres in a Country                   418267  2005
# 4  All Urban Centres in a Country                  2464143  2005
#
#   air_pollutant       health_risk_scenario  populated_area_[km2]  \
# 0         PM2.5  WHO_2005_HRAPIE_Scen_Base                   446
# 1         PM2.5  WHO_2005_HRAPIE_Scen_Base                   745
# 2         PM2.5  WHO_2005_HRAPIE_Scen_Base                   384
# 3         PM2.5  WHO_2005_HRAPIE_Scen_Base                   131
# 4         PM2.5  WHO_2005_HRAPIE_Scen_Base                   536
#
#    air_pollution_average_[ug/m3]  \
# 0                           21.6
# 1                           19.0
# 2                           34.2
# 3                           29.5
# 4                           24.4
#
#    air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# 0                                               22.0            2532.0
# 1                                               19.3            3025.0
# 2                                               34.6            7927.0
# 3                                               29.6             460.0
# 4                                               24.6            3330.0
#
#    premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# 0                       1687.0                       3287.0
# 1                       2013.0                       3936.0
# 2                       5363.0                      10157.0
# 3                        310.0                        592.0
# 4                       2231.0                       4315.0
#
#    years_of_life_lost  years_of_life_lost_-_lower_ci  \
# 0             27563.0                        18385.0
# 1             32439.0                        21580.0
# 2             85612.0                        57929.0
# 3              4835.0                         3249.0
# 4             36733.0                        24581.0
#
#    years_of_life_lost_-_upper_ci      density
# 0                        35772.0  5393.825112
# 1                        42208.0  4067.971812
# 2                       109669.0  7840.955729
# 3                         6231.0  3192.877863
# 4                        47529.0  4597.281716

# %%
df_cleanedgpw3.describe(include='all')
# Out:
#        city_boundary_specification_(lau/grid) country_or_territory  \
# count                                   70176                70176
# unique                                      2                   28
# top            ESTAT Urban Audit Cities (LAU)                Spain
# freq                                    36384                11520
# mean                                      NaN                  NaN
# std                                       NaN                  NaN
# min                                       NaN                  NaN
# 25%                                       NaN                  NaN
# 50%                                       NaN                  NaN
# 75%                                       NaN                  NaN
# max                                       NaN                  NaN
#
#                                   city  total_city_population_*         year  \
# count                            70176             7.017600e+04  70176.00000
# unique                             908                      NaN          NaN
# top     All Urban Centres in a Country                      NaN          NaN
# freq                              1296                      NaN          NaN
# mean                               NaN             4.390408e+05   2013.43750
# std                                NaN             4.092880e+06      4.71661
# min                                NaN             1.120500e+04   2005.00000
# 25%                                NaN             7.135300e+04   2009.75000
# 50%                                NaN             1.083410e+05   2013.50000
# 75%                                NaN             2.030148e+05   2017.25000
# max                                NaN             1.499694e+08   2021.00000
#
#        air_pollutant       health_risk_scenario  populated_area_[km2]  \
# count          70176                      70176          70176.000000
# unique             1                          3                   NaN
# top            PM2.5  WHO_2005_HRAPIE_Scen_Base                   NaN
# freq           70176                      23392                   NaN
# mean             NaN                        NaN            138.323259
# std              NaN                        NaN            826.944715
# min              NaN                        NaN              3.000000
# 25%              NaN                        NaN             21.000000
# 50%              NaN                        NaN             50.000000
# 75%              NaN                        NaN            119.000000
# max              NaN                        NaN          29537.000000
#
#         air_pollution_average_[ug/m3]  \
# count                    70176.000000
# unique                            NaN
# top                               NaN
# freq                              NaN
# mean                        15.137504
# std                          5.413934
# min                          2.500000
# 25%                         11.400000
# 50%                         14.200000
# 75%                         18.000000
# max                         45.200000
#
#         air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# count                                        70176.000000      70176.000000
# unique                                                NaN               NaN
# top                                                   NaN               NaN
# freq                                                  NaN               NaN
# mean                                            15.740434        416.242661
# std                                              5.692994       3960.025786
# min                                              3.000000          0.000000
# 25%                                             11.800000         57.000000
# 50%                                             14.800000         95.000000
# 75%                                             18.500000        186.000000
# max                                             45.300000     204982.000000
#
#         premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# count                  70176.000000                 70176.000000
# unique                          NaN                          NaN
# top                             NaN                          NaN
# freq                            NaN                          NaN
# mean                     306.308667                   487.765974
# std                     2931.584406                  4634.351795
# min                        0.000000                     0.000000
# 25%                       41.000000                    67.000000
# 50%                       69.000000                   111.000000
# 75%                      137.000000                   219.000000
# max                   158597.000000                227129.000000
#
#         years_of_life_lost  years_of_life_lost_-_lower_ci  \
# count         7.017600e+04                   7.017600e+04
# unique                 NaN                            NaN
# top                    NaN                            NaN
# freq                   NaN                            NaN
# mean          4.678110e+03                   3.443085e+03
# std           4.465474e+04                   3.306458e+04
# min           0.000000e+00                   0.000000e+00
# 25%           6.280000e+02                   4.540000e+02
# 50%           1.069000e+03                   7.810000e+02
# 75%           2.095000e+03                   1.543000e+03
# max           2.309732e+06                   1.786895e+06
#
#         years_of_life_lost_-_upper_ci       density
# count                    7.017600e+04  70176.000000
# unique                            NaN           NaN
# top                               NaN           NaN
# freq                              NaN           NaN
# mean                     5.481211e+03   3536.933578
# std                      5.224701e+04   2668.298656
# min                      0.000000e+00     46.847738
# 25%                      7.400000e+02   1515.317073
# 50%                      1.260000e+03   3057.733333
# 75%                      2.462000e+03   4782.243477
# max                      2.559184e+06  32865.600000

# %%
#graphe air pollution
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))

# Plot 'air_pollution_average_[ug/m3]' vs 'populated_area_[km2]'
sns.lineplot(x='populated_area_[km2]', y='air_pollution_average_[ug/m3]', data=df_cleanedgpw3, label='Average Air Pollution [ug/m3]', marker='o')

# Plot 'air_pollution_population_weighted_average_[ug/m3]' vs 'populated_area_[km2]'
sns.lineplot(x='populated_area_[km2]', y='air_pollution_population_weighted_average_[ug/m3]', data=df_cleanedgpw3, label='Population Weighted Air Pollution [ug/m3]', marker='o')

# Add titles and labels
plt.title('Air Pollution by Size of the Populated Area')
plt.xlabel('Populated Area [km²]')
plt.ylabel('Air Pollution [µg/m³]')
plt.legend()
plt.grid(True)

# Display the plot
file_path = pathpics + '\\air_pollution_in_europe_by_populated_area.jpg'     
plt.savefig(file_path, format='jpeg', dpi=300)
plt.show()
#The average air pollution per area seems doesn't sems affected by the density of the population.

# %%
#check for cities present => too many possible values
unique_cities_list = df_cleanedgpw3['city'].unique().tolist()
print(unique_cities_list)
# Out:
# ['All Urban Centres in a Country', 'All Urban Centres in EU27', 'Wien', 'Graz', 'Linz', 'Salzburg', 'Innsbruck', 'Klagenfurt', 'Bruxelles / Brussel', 'Antwerpen', 'Gent', 'Charleroi', 'Liège', 'Brugge', 'Namur', 'Leuven', 'Mons', 'Kortrijk', 'Oostende', 'Mechelen', 'Mouscron', 'La Louvière (greater city)', 'Verviers (greater city)', 'Sofia', 'Plovdiv', 'Varna', 'Burgas', 'Pleven', 'Ruse', 'Vidin', 'Stara Zagora', 'Sliven', 'Dobrich', 'Shumen', 'Pernik', 'Yambol', 'Haskovo', 'Pazardzhik', 'Blagoevgrad', 'Veliko Tarnovo', 'Vratsa', 'Lefkosia', 'Larnaka', 'Lemesos', 'Praha', 'Brno', 'Ostrava', 'Plzen', 'Ústí nad Labem', 'Olomouc', 'Liberec', 'Ceské Budejovice', 'Hradec Králové', 'Pardubice', 'Zlín', 'Kladno', 'Karlovy Vary', 'Jihlava', 'Havírov', 'Most', 'Karviná', 'Chomutov-Jirkov', 'Berlin', 'Hamburg', 'München', 'Köln', 'Frankfurt am Main', 'Essen', 'Stuttgart', 'Leipzig', 'Dresden', 'Dortmund', 'Düsseldorf', 'Bremen', 'Hannover', 'Nürnberg', 'Bochum', 'Bielefeld', 'Halle an der Saale', 'Magdeburg', 'Wiesbaden', 'Göttingen', 'Mülheim a.d.Ruhr', 'Moers', 'Darmstadt', 'Trier', 'Freiburg im Breisgau', 'Regensburg', 'Frankf
manresa', 'Getxo', 'Rubí', 'Ciudad Real', 'Benidorm', 'Melilla', 'Viladecans', 'Ponferrada', 'San Sebastián de los Reyes', 'Zamora', 'Fuengirola', 'Cerdanyola del Vallès', 'Sanlúcar de Barrameda', 'Vilanova i la Geltrú', 'Prat de Llobregat, El', 'Línea de la Concepción, La', 'Cornellà de Llobregat', 'Majadahonda', 'Torremolinos', 'Castelldefels', 'Irun', 'Granollers', 'Elda', 'Mollet del Vallès', 'Granada', 'Badalona', 'Móstoles', 'Elche/Elx', 'Cartagena', 'Sabadell', 'Jerez de la Frontera', 'Fuenlabrada', 'San Sebastián/Donostia', 'Alcalá de Henares', 'Terrassa', 'Leganés', 'Almería', 'Burgos', 'Salamanca', 'Alcorcón', ...

# %%
#print(df_cleanedgpw3[df_cleanedgpw3['city'] == 'Grenoble'])

# %%
#graphe of air pollution through time  in EU
sns.set(style="whitegrid")

# Create the plot
plt.figure(figsize=(10, 6))

# Plot 'air_pollution_average_[ug/m3]' vs 'time' 
sns.lineplot(x='year', y='air_pollution_average_[ug/m3]', data=df_cleanedgpw3, label='Average Air Pollution [ug/m3]', marker='o')




# Add titles and labels
plt.title('Average Air Pollution in Europe For Small Particles')
plt.xlabel('Year')
plt.ylabel('Average Air Pollution [µg/m³]')
plt.legend()
plt.grid(True)

# Display the plot
file_path = pathpics + '\\Average_Air_Pollution_in_Europe_For_Small_Particles_Per_Year.jpg'     
plt.savefig(file_path, format='jpeg', dpi=300)
plt.show()

# %%
#graphe of air pollution through time and premature death in EU

sns.set(style="whitegrid")

# Create the figure and axis
fig, ax1 = plt.subplots(figsize=(12, 8))

# Plot 'air_pollution_average_[ug/m3]' vs 'year' on ax1
sns.lineplot(x='year', y='air_pollution_average_[ug/m3]', data=df_cleanedgpw3, ax=ax1, label='Average Air Pollution [µg/m³]', color='blue', marker='o')

# Set label for the first y-axis
ax1.set_ylabel('Average Air Pollution [µg/m³]', color='blue')
ax1.tick_params(axis='y', labelcolor='blue')

# Create a twin axis sharing the x-axis with ax1
ax2 = ax1.twinx()

# Plot 'premature_deaths' vs 'year' on ax2
sns.lineplot(x='year', y='premature_deaths', data=df_cleanedgpw3, ax=ax2, label='Premature Deaths', color='red', marker='o')

# Set label for the second y-axis
ax2.set_ylabel('Premature Deaths', color='red')
ax2.tick_params(axis='y', labelcolor='red')

# Add titles and labels
plt.title('Air Pollution and Premature Deaths in Europe Over Time')
ax1.set_xlabel('Year')

# Add legend
fig.legend(loc="upper right", bbox_to_anchor=(1,1), bbox_transform=ax1.transAxes)

# Display the plot
plt.grid(True)
plt.show()

# Save the plot as a JPEG file
file_path = pathpics + '\\air_pollution_vs_premature_deaths.jpg'     
fig.savefig(file_path, format='jpeg', dpi=300)

# %%
# Step 1: Filter the DataFrame for the year 2021
df_2021 = df_cleanedgpw3[df_cleanedgpw3['year'] == 2021]

# Step 2: Sort the DataFrame by 'total_city_population_*' in descending order
df_sorted = df_2021.sort_values(by='total_city_population_*', ascending=False)

# Step 3: Drop rows where the 'city' value is 'All Urban Centres in EU27' or 'All Urban Centres in a Country'
cities_to_exclude = ['All Urban Centres in EU27', 'All Urban Centres in a Country']
df_sorted_filtered = df_sorted[~df_sorted['city'].isin(cities_to_exclude)]

# Step 4: Drop rows where 'city_boundary_specification_(lau/grid)' is not 'ESTAT Urban Audit Cities (LAU)'
df_final_filtered = df_sorted_filtered[df_sorted_filtered['city_boundary_specification_(lau/grid)'] == 'ESTAT Urban Audit Cities (LAU)']

# Step 5: Drop duplicates to ensure unique maximum values
df_unique = df_final_filtered.drop_duplicates(subset='total_city_population_*')

# %%
df_unique.head(32)
# Out:
#       city_boundary_specification_(lau/grid) country_or_territory  \
# 53958         ESTAT Urban Audit Cities (LAU)               France
# 51813         ESTAT Urban Audit Cities (LAU)                Spain
# 51844         ESTAT Urban Audit Cities (LAU)                Spain
# 65614         ESTAT Urban Audit Cities (LAU)                Italy
# 49578         ESTAT Urban Audit Cities (LAU)              Germany
# 51588         ESTAT Urban Audit Cities (LAU)               Greece
# 51483         ESTAT Urban Audit Cities (LAU)              Denmark
# 51800         ESTAT Urban Audit Cities (LAU)                Spain
# 65643         ESTAT Urban Audit Cities (LAU)                Italy
# 65584         ESTAT Urban Audit Cities (LAU)                Italy
# 68028         ESTAT Urban Audit Cities (LAU)               Poland
# 68929         ESTAT Urban Audit Cities (LAU)             Portugal
# 69289         ESTAT Urban Audit Cities (LAU)              Romania
# 49593         ESTAT Urban Audit Cities (LAU)              Germany
# 69830         ESTAT Urban Audit Cities (LAU)               Sweden
# 48678         ESTAT Urban Audit Cities (LAU)              Austria
# 65225         ESTAT Urban Audit Cities (LAU)              Hungary
# 67878         ESTAT Urban Audit Cities (LAU)               Poland
# 51828         ESTAT Urban Audit Cities (LAU)                Spain
# 65600         ESTAT Urban Audit Cities (LAU)                Italy
# 51874         ESTAT Urban Audit Cities (LAU)                Spain
# 49610         ESTAT Urban Audit Cities (LAU)              Germany
# 67204         ESTAT Urban Audit Cities (LAU)          Netherlands
# 49310         ESTAT Urban Audit Cities (LAU)              Czechia
# 48768         ESTAT Urban Audit Cities (LAU)              Belgium
# 48995         ESTAT Urban Audit Cities (LAU)             Bulgaria
# 65628         ESTAT Urban Audit Cities (LAU)                Italy
# 53974         ESTAT Urban Audit Cities (LAU)               France
# 49623         ESTAT Urban Audit Cities (LAU)              Germany
# 69814         ESTAT Urban Audit Cities (LAU)               Sweden
# 68958         ESTAT Urban Audit Cities (LAU)             Portugal
# 53823         ESTAT Urban Audit Cities (LAU)              Finland
#
#                                         city  total_city_population_*  year  \
# 53958                   Paris (greater city)                 10183494  2021
# 51813                                 Madrid                  5143538  2021
# 51844                              Barcelona                  3742186  2021
# 65614                  Milano (greater city)                  3650812  2021
# 49578                                 Berlin                  3477391  2021
# 51588                                 Athina                  3401273  2021
# 51483                              København                  3205378  2021
# 51800                                 Madrid                  3194925  2021
#
#        air_pollution_average_[ug/m3]  \
# 53958                           11.1
#
#        air_pollution_population_weighted_average_[ug/m3]  premature_deaths  \
# 53958                                               11.7            6393.0
#
#        premature_deaths_-_lower_ci  premature_deaths_-_upper_ci  \
# 53958                       4218.0                       8379.0
#
#        years_of_life_lost  years_of_life_lost_-_lower_ci  \
# 53958             68244.0                        45040.0
#
#        years_of_life_lost_-_upper_ci     density
# 53958                        89442.0  5238.42284

# %%
df_unique = df_unique[~df_unique['city'].str.contains('Paris', case=False)]

# %%
display(df_unique[df_unique['city'].str.contains('Paris', case=False)])
# Out:
# Empty DataFrame
# Columns: [city_boundary_specification_(lau/grid), country_or_territory, city, total_city_population_*, year, air_pollutant, health_risk_scenario, populated_area_[km2], air_pollution_average_[ug/m3], air_pollution_population_weighted_average_[ug/m3], premature_deaths, premature_deaths_-_lower_ci, premature_deaths_-_upper_ci, years_of_life_lost, years_of_life_lost_-_lower_ci, years_of_life_lost_-_upper_ci, density]
# Index: []

# %%
# Step 6: Create 3 tables per scenario
#df_scenario2005 = df_unique[df_unique['health_risk_scenario'] == 'WHO_2005_HRAPIE_Scen_Base'].reset_index(drop=True).head(10)
#df_scenario2021_base = df_unique[df_unique['health_risk_scenario'] == 'WHO_2021_AQG_Scen_Sensitivity_2'].reset_index(drop=True).head(10)
#df_scenario2021_sensitivity = df_unique[df_unique['health_risk_scenario'] == 'WHO_2021_AQG_Scen_Sensitivity_2'].reset_index(drop=True).head(10)

df_scenario2005 = df_unique[df_unique['health_risk_scenario'] == 'WHO_2005_HRAPIE_Scen_Base'].reset_index(drop=True).iloc[:10]
df_scenario2021_base = df_unique[df_unique['health_risk_scenario'] == 'WHO_2021_AQG_Scen_Sensitivity_2'].reset_index(drop=True).iloc[:10]
df_scenario2021_sensitivity = df_unique[df_unique['health_risk_scenario'] == 'WHO_2021_AQG_Scen_Sensitivity_2'].reset_index(drop=True).iloc[:10]

# Step 7: Keep only the columns you want to retain
columns_to_keep = ['city', 'total_city_population_*', 'air_pollution_average_[ug/m3]', 'premature_deaths', 'years_of_life_lost', 'density']
df_scenario2005_bis = df_scenario2005[columns_to_keep].copy()
df_scenario2021_base_bis = df_scenario2021_base[columns_to_keep].copy()
df_scenario2021_sensitivity_bis = df_scenario2021_sensitivity[columns_to_keep].copy()

# Step 8: Add a 'source' column to each DataFrame
df_scenario2005_bis.loc[:, 'source'] = 'df_scenario2005_bis'
df_scenario2021_base_bis.loc[:, 'source'] = 'df_scenario2021_base_bis'
df_scenario2021_sensitivity_bis.loc[:, 'source'] = 'df_scenario2021_sensitivity_bis'

# Create a common dataset
df_top10 = pd.concat([df_scenario2005_bis, df_scenario2021_base_bis, df_scenario2021_sensitivity_bis], ignore_index=True)

# %%
print("List of the 10 largest cities in Europe:")
print(list(df_scenario2005_bis['city']))
print(list(df_scenario2021_base_bis['city']))
print(list(df_scenario2021_sensitivity_bis['city']))
# Out:
# List of the 10 largest cities in Europe:
# ['Madrid', 'Berlin', 'Athina', 'København', 'Napoli (greater city)', 'Górnoslaski Zwiazek Metropolitalny', 'Hamburg', 'Wien', 'Warszawa', 'Barcelona']
# ['Madrid', 'Stockholm (greater city)', 'Budapest', 'Milano', 'München', 'Praha', 'Sofia', 'Greater Amsterdam', 'Frankfurt am Main', 'Kraków']
# ['Madrid', 'Stockholm (greater city)', 'Budapest', 'Milano', 'München', 'Praha', 'Sofia', 'Greater Amsterdam', 'Frankfurt am Main', 'Kraków']

# %%
basic_stats_2005 = df_scenario2005_bis.describe(include='all')
basic_stats_2021_base = df_scenario2021_base_bis.describe(include='all')
basic_stats_2021_sensitivity = df_scenario2021_sensitivity_bis.describe(include='all')

print("Basic Statistics for scenario 2005:")
print(basic_stats_2005)
print("\nBasic Statistics for scenario 2021 base:")
print(basic_stats_2021_base)
print("\nBasic Statistics for scenario 2021 sensitivity:")
print(basic_stats_2021_sensitivity)
# Out:
# Basic Statistics for scenario 2005:
#                         city  total_city_population_*  \
# count                     10             1.000000e+01
# unique                    10                      NaN
# top     Paris (greater city)                      NaN
# freq                       1                      NaN
# mean                     NaN             3.572338e+06
# std                      NaN             2.553676e+06
# min                      NaN             1.718025e+06
# 25%                      NaN             1.891495e+06
# 50%                      NaN             3.060826e+06
# 75%                      NaN             3.458362e+06
# max                      NaN             1.018349e+07
#
#         air_pollution_average_[ug/m3]  premature_deaths  years_of_life_lost  \
# count                       10.000000           10.0000            10.00000
# unique                            NaN               NaN                 NaN
# top                               NaN               NaN                 NaN
# freq                              NaN               NaN                 NaN
# mean                        13.480000         2890.6000         30084.10000
# std                          5.248661         1590.5809         17016.27356
# min                          8.200000         1139.0000         11502.00000
# 25%                         10.000000         1672.5000         16851.50000
# 50%                         11.450000         2730.5000         29646.00000
# 75%                         16.025000         3452.2500         37484.00000
# max                         24.300000         6393.0000         68244.00000
#
#             density
# count     10.000000
# unique          NaN
# top             NaN
# freq            NaN
# mean    4250.149166
# std     1970.043244
# min     1760.328571
# 25%     3165.686079
# 50%     3629.007461
# 75%     5065.631327
# max     8125.652449
#
# Basic Statistics for scenario 2021 base:
#           city  total_city_population_*  air_pollution_average_[ug/m3]  \
# count       10             1.000000e+01                      10.000000
# unique      10                      NaN                            NaN
# top     Madrid                      NaN                            NaN
# freq         1                      NaN                            NaN
# mean       NaN             1.473536e+06                      12.770000
# std        NaN             7.089587e+05                       5.857768
# min        NaN             7.692620e+05                       4.700000
# 25%        NaN             1.018286e+06                       9.775000
# 50%        NaN             1.369184e+06                      11.550000
# 75%        NaN             1.681876e+06                      14.700000
# max        NaN             3.194925e+06                      24.600000
#
#         premature_deaths  years_of_life_lost       density
# count          10.000000           10.000000     10.000000
# unique               NaN                 NaN           NaN
# top                  NaN                 NaN           NaN
# freq                 NaN                 NaN           NaN
# mean         1722.200000        17379.000000   4104.541851
# std           943.492425         9532.713162   3251.791352
# min           635.000000         6028.000000   1615.726638
# 25%           778.750000         8018.250000   2154.255666
# 50%          1749.000000        18534.500000   3215.233074
# 75%          2408.750000        23458.500000   3932.641377
# max          3061.000000        33103.000000  12431.614786
#
# Basic Statistics for scenario 2021 sensitivity:
#           city  total_city_population_*  air_pollution_average_[ug/m3]  \
# count       10             1.000000e+01                      10.000000
# unique      10                      NaN                            NaN
# top     Madrid                      NaN                            NaN
# freq         1                      NaN                            NaN
# mean       NaN             1.473536e+06                      12.770000
# std        NaN             7.089587e+05                       5.857768
# min        NaN             7.692620e+05                       4.700000
# 25%        NaN             1.018286e+06                       9.775000
# 50%        NaN             1.369184e+06                      11.550000
# 75%        NaN             1.681876e+06                      14.700000
# max        NaN             3.194925e+06                      24.600000
#
#         premature_deaths  years_of_life_lost       density
# count          10.000000           10.000000     10.000000
# unique               NaN                 NaN           NaN
# top                  NaN                 NaN           NaN
# freq                 NaN                 NaN           NaN
# mean         1722.200000        17379.000000   4104.541851
# std           943.492425         9532.713162   3251.791352
# min           635.000000         6028.000000   1615.726638
# 25%           778.750000         8018.250000   2154.255666
# 50%          1749.000000        18534.500000   3215.233074
# 75%          2408.750000        23458.500000   3932.641377
# max          3061.000000        33103.000000  12431.614786

# %%
#The inconsistency of the raws based on the column city made it difficult to draw summarized information from it.

# %%
columns_to_plot = ['total_city_population_*', 'air_pollution_average_[ug/m3]', 'premature_deaths', 'years_of_life_lost', 'density']

for column in columns_to_plot:
    plt.figure(figsize=(10, 5))
    plt.bar(df_top10['city'], df_top10_bis[column], color='skyblue')
    plt.xticks(rotation=90)
    plt.title(f'{column} by City')
    plt.xlabel('City')
    plt.ylabel(column)
    plt.show()
# Set the x-axis labels to smaller font size
   # plt.xticks(ticks=range(len(df_scenario2021_sensitivity_bis['city'])), labels=[city.lower() for city in df_scenario2021_sensitivity_bis['city']], fontsize=10)

# %%
display(df_top10)
# Out:
#                                   city  total_city_population_*  \
# 0                 Paris (greater city)                 10183494
# 1                               Madrid                  5143538
# 2                               Berlin                  3477391
# 3                               Athina                  3401273
# 4                            København                  3205378
# 5                Napoli (greater city)                  2916275
# 6   Górnoslaski Zwiazek Metropolitalny                  1971568
# 7                              Hamburg                  1864804
# 8                                 Wien                  1841639
# 9                             Warszawa                  1718025
# 10                              Madrid                  3194925
# 11            Stockholm (greater city)                  1850007
# 12                            Budapest                  1748672
# 13                              Milano                  1481490
# 14                             München                  1434946
# 15                               Praha                  1303422
# 16                               Sofia                  1220559
# 17                   Greater Amsterdam                   950862
# 18                   Frankfurt am Main                   781212
# 19                              Kraków                   769262
# 20                              Madrid                  3194925
# 21            Stockholm (greater city)                  1850007
# 22                            Budapest                  1748672
# 23                              Milano                  1481490
# 24                             München                  1434946
# 25                               Praha                  1303422
# 26                               Sofia                  1220559
# 27                   Greater Amsterdam                   950862
# 28                   Frankfurt am Main                   781212
# 29                              Kraków                   769262
#
#     air_pollution_average_[ug/m3]  premature_deaths  years_of_life_lost  \
# 0                            11.1            6393.0             68244.0
# 1                             9.8            2782.0             30338.0
# 2                            11.8            2904.0             29886.0
# 3                            17.2            4200.0             41234.0
# 4                             8.2            1380.0             14922.0
# 5                            12.5            2550.0             22640.0
# 6                            24.3            3635.0             39866.0
# 7                             9.4            1244.0             12803.0
# 8                            10.6            1139.0             11502.0
# 9                            19.9            2679.0             29406.0
# 10                           10.0            2195.0             23938.0
# 11                            4.7             665.0              6028.0
# 12                           15.2            3061.0             33103.0
# 13                           19.6            2480.0             22020.0
# 14                            7.6            1024.0             10545.0
# 15                           13.0            1622.0             16485.0
# 16                           13.2            2967.0             27323.0
# 17                            9.7             635.0              6588.0
# 18                           10.1             697.0              7176.0
# 19                           24.6            1876.0             20584.0
# 20                           10.0            2195.0             23938.0
# 21                            4.7             665.0              6028.0
# 22                           15.2            3061.0             33103.0
# 23                           19.6            2480.0             22020.0
# 24                            7.6            1024.0             10545.0
# 25                           13.0            1622.0             16485.0
# 26                           13.2            2967.0             27323.0
# 27                            9.7             635.0              6588.0
# 28                           10.1             697.0              7176.0
# 29                           24.6            1876.0             20584.0
#
#          density                           source
# 0    5238.422840              df_scenario2005_bis
# 1    8125.652449              df_scenario2005_bis
# 2    3951.580682              df_scenario2005_bis
# 3    6735.194059              df_scenario2005_bis
# 4    3257.497967              df_scenario2005_bis
# 5    3306.434240              df_scenario2005_bis
# 6    1760.328571              df_scenario2005_bis
# 7    2444.041940              df_scenario2005_bis
# 8    4547.256790              df_scenario2005_bis
# 9    3135.082117              df_scenario2005_bis
# 10  12431.614786         df_scenario2021_base_bis
# 11   1615.726638         df_scenario2021_base_bis
# 12   3305.618147         df_scenario2021_base_bis
# 13   6584.400000         df_scenario2021_base_bis
# 14   4135.291066         df_scenario2021_base_bis
# 15   2431.757463         df_scenario2021_base_bis
# 16   2061.755068         df_scenario2021_base_bis
# 17   3324.692308         df_scenario2021_base_bis
# 18   3124.848000         df_scenario2021_base_bis
# 19   2029.715040         df_scenario2021_base_bis
# 20  12431.614786  df_scenario2021_sensitivity_bis
# 21   1615.726638  df_scenario2021_sensitivity_bis
# 22   3305.618147  df_scenario2021_sensitivity_bis
# 23   6584.400000  df_scenario2021_sensitivity_bis
# 24   4135.291066  df_scenario2021_sensitivity_bis
# 25   2431.757463  df_scenario2021_sensitivity_bis
# 26   2061.755068  df_scenario2021_sensitivity_bis
# 27   3324.692308  df_scenario2021_sensitivity_bis
# 28   3124.848000  df_scenario2021_sensitivity_bis
# 29   2029.715040  df_scenario2021_sensitivity_bis

# %%
plt.figure(figsize=(14, 8))

# Plotting the data
sns.barplot(x='city', y='premature_deaths', hue='source', data=df_top10)
plt.title('Premature Deaths by City and Source')
plt.xticks(rotation=45)
plt.show()

plt.figure(figsize=(14, 8))
sns.barplot(x='city', y='years_of_life_lost', hue='source', data=df_top10)
plt.title('Years of Life Lost by City and Source')
plt.xticks(rotation=45)
plt.show()
